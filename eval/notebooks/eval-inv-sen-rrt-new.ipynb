# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[1.39887064, 0.07879974]])[0]
time_step = 82

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.43674138, 1.57625727]])[0]
print(ref_traj[0], ref_traj[time_step])
rand_area = [[1.0, 1.0], [4.0, 4.0]]
evalObject.reachDestInvRRTPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[1], scaling_factors=[0.02], i_state=[ref_traj[0]], 
                                adaptation_run=True, rand_area=rand_area, n_paths=3)
# Out:
# [1.39887064 0.07879974] [0.67042778 0.87705564]
# [0.43674138 1.57625727] [0.58046043 1.83329783]
# Model file ../../eval/models/model_vp_2_v_Brussellator_RBF_1_256_ReLU_supp.h5
# [[array([0.58046043, 1.83329783]), array([1.01373778, 2.0828389 ])], [array([1.01373778, 2.0828389 ]), array([1.502156  , 2.18983255])], [array([1.502156  , 2.18983255]), array([1.53382009, 1.69083617])], [array([1.53382009, 1.69083617]), array([1.12014567, 1.40999197])], [array([1.12014567, 1.40999197]), array([0.79768806, 1.02786491])], [array([0.79768806, 1.02786491]), array([0.67042778, 0.87705564])]]
# [[array([0.58046043, 1.83329783]), array([0.95296877, 1.49977491])], [array([0.95296877, 1.49977491]), array([0.74637835, 1.04445041])], [array([0.74637835, 1.04445041]), array([0.67042778, 0.87705564])]]
# [[array([0.58046043, 1.83329783]), array([0.62729573, 1.33549621])], [array([0.62729573, 1.33549621]), array([0.67042778, 0.87705564])]]
# ***** path idx 0 s_factor 0.02 correction steps 1
# [0.58046043 1.83329783] [1.01373778 2.0828389 ]
# 500
# Starting distance: 0.49999999999999983
# Before adaptation relative distance 0.3445489042680314
# Adaptations reached it's limits
# Final relative distance 0.3445489049557521
# Min relative distance 0.3445489042680314
# Min iter: 94
# Before adaptation iterations: 95
# Final iterations: 96
# ***** path idx 1 s_factor 0.02 correction steps 1
# [1.01373778 2.0828389 ] [1.502156   2.18983255]
# 500
# Starting distance: 0.5
# Before adaptation relative distance 1.0
# Adaptations reached it's limits
# Final relative distance 1.269028619119522
# Min relative distance 1.0
# Min iter: 0
# Before adaptation iterations: 1
# Final iterations: 163
# ***** path idx 2 s_factor 0.02 correction steps 1
# [1.502156   2.18983255] [1.53382009 1.69083617]
# 500
# Starting distance: 0.5
# Before adaptation relative distance 1.0
# Before adaptation relative distance 0.8717832293443248
# Adaptations reached it's limits
# Final relative distance 0.8717832295390033
# Min relative distance 0.8717832293443248
# Min iter: 109
# Before adaptation iterations: 1
# Final iterations: 112
# ***** path idx 3 s_factor 0.02 correction steps 1
# [1.53382009 1.69083617] [1.12014567 1.40999197]
# 500
# Starting distance: 0.5000000000000001
# Final relative distance 0.0008852365138233914
# Min relative distance 0.0008852365138233914
# Min iter: 20
# Before adaptation iterations: 20
# Final iterations: 20
# ***** path idx 4 s_factor 0.02 correction steps 1
# [1.12014567 1.40999197] [0.79768806 1.02786491]
# 500
# Starting distance: 0.5
# Final relative distance 0.0042684126315073335
# Min relative distance 0.0042684126315073335
# Min iter: 28
# Before adaptation iterations: 28
# Final iterations: 28
# ***** path idx 5 s_factor 0.02 correction steps 1
# [0.79768806 1.02786491] [0.67042778 0.87705564]
# 500
# Starting distance: 0.19732869278082074
# Final relative distance 0.027235303579670106
# Min relative distance 0.027235303579670106
# Min iter: 11
# Before adaptation iterations: 11
# Final iterations: 11
# Time taken: 20.934163808822632
# ***** path idx 0 s_factor 0.02 correction steps 1
# [0.58046043 1.83329783] [0.95296877 1.49977491]
# 500
# Starting distance: 0.49999999999999994
# Final relative distance 0.01716885370621858
# Min relative distance 0.01716885370621858
# Min iter: 25
# Before adaptation iterations: 25
# Final iterations: 25
# ***** path idx 1 s_factor 0.02 correction steps 1
# [0.95296877 1.49977491] [0.74637835 1.04445041]
# 500
# Starting distance: 0.5
# Final relative distance 0.008354800171231773
# Min relative distance 0.008354800171231773
# Min iter: 27
# Before adaptation iterations: 27
# Final iterations: 27
# ***** path idx 2 s_factor 0.02 correction steps 1
# [0.74637835 1.04445041] [0.67042778 0.87705564]
# 500
# Starting distance: 0.1838192002610244
# Final relative distance 0.0049636864125000004
# Min relative distance 0.0049636864125000004
# Min iter: 11
# Before adaptation iterations: 11
# Final iterations: 11
# Time taken: 2.6844093799591064
# ***** path idx 0 s_factor 0.02 correction steps 1
# [0.58046043 1.83329783] [0.62729573 1.33549621]
# 500
# Starting distance: 0.4999999999999999
# Final relative distance 0.016369232298403025
# Min relative distance 0.016369232298403025
# Min iter: 25
# Before adaptation iterations: 25
# Final iterations: 25
# ***** path idx 1 s_factor 0.02 correction steps 1
# [0.62729573 1.33549621] [0.67042778 0.87705564]
# 500
# Starting distance: 0.46046511976262666
# Final relative distance 0.002693368274659539
# Min relative distance 0.002693368274659539
# Min iter: 25
# Before adaptation iterations: 25
# Final iterations: 25
# Time taken: 1.9401171207427979

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Buckling')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.63202423, 0.78686457]])[0]
time_step = 101

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[1.62511067, 1.72110143]])[0]
print(ref_traj[0], ref_traj[time_step])
rand_area = [[0.0, 0.0], [3.0, 3.0]]
evalObject.reachDestInvRRTPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[1], scaling_factors=[0.02], i_state=[ref_traj[0]], 
                                adaptation_run=True, rand_area=rand_area, n_paths=1)
# Out:
# [0.63202423 0.78686457] [1.77328142 0.97363752]
# [1.62511067 1.72110143] [ 1.55625323 -1.5925081 ]
# Model file ../../eval/models/model_vp_2_v_Buckling_RBF_1_256_ReLU_supp.h5
# [[array([ 1.55625323, -1.5925081 ]), array([ 1.43284272, -1.10797756])], [array([ 1.43284272, -1.10797756]), array([ 1.45210777, -0.60834884])], [array([ 1.45210777, -0.60834884]), array([ 1.32263824, -0.12540201])], [array([ 1.32263824, -0.12540201]), array([1.15579088, 0.34593858])], [array([1.15579088, 0.34593858]), array([1.3498372 , 0.80674876])], [array([1.3498372 , 0.80674876]), array([1.77328142, 0.97363752])]]
# ***** path idx 0 s_factor 0.02 correction steps 1
# [ 1.55625323 -1.5925081 ] [ 1.43284272 -1.10797756]
# 500
# Starting distance: 0.5
# Final relative distance 0.018663607047647548
# Min relative distance 0.018663607047647548
# Min iter: 24
# Before adaptation iterations: 24
# Final iterations: 24
# ***** path idx 1 s_factor 0.02 correction steps 1
# [ 1.43284272 -1.10797756] [ 1.45210777 -0.60834884]
# 500
# Starting distance: 0.49999999999999994
# Final relative distance 0.013044796378115486
# Min relative distance 0.013044796378115486
# Min iter: 23
# Before adaptation iterations: 23
# Final iterations: 23
# ***** path idx 2 s_factor 0.02 correction steps 1
# [ 1.45210777 -0.60834884] [ 1.32263824 -0.12540201]
# 500
# Starting distance: 0.5
# Before adaptation relative distance 0.18215591589381985
# Adaptations reached it's limits
# Final relative distance 0.18215591842200538
# Min relative distance 0.18215591589381985
# Min iter: 67
# Before adaptation iterations: 68
# Final iterations: 69
# ***** path idx 3 s_factor 0.02 correction steps 1
# [ 1.32263824 -0.12540201] [1.15579088 0.34593858]
# 500
# Starting distance: 0.5
# Before adaptation relative distance 1.0
# Before adaptation relative distance 0.8870399783189342
# Adaptations reached it's limits
# Final relative distance 0.8870399794449251
# Min relative distance 0.8870399783189342
# Min iter: 220
# Before adaptation iterations: 1
# Final iterations: 226
# ***** path idx 4 s_factor 0.02 correction steps 1
# [1.15579088 0.34593858] [1.3498372  0.80674876]
# 500
# Starting distance: 0.5000000000000001
# Before adaptation relative distance 1.0
# Before adaptation relative distance 0.14753606277755235
# Adaptations reached it's limits
# Final relative distance 0.14753606321870189
# Min relative distance 0.14753606277755235
# Min iter: 99
# Before adaptation iterations: 1
# Final iterations: 101
# ***** path idx 5 s_factor 0.02 correction steps 1
# [1.3498372  0.80674876] [1.77328142 0.97363752]
# 500
# Starting distance: 0.45514487924885766
# Before adaptation relative distance 0.027710227411162407
# Final relative distance 0.018074802831046313
# Min relative distance 0.018074802831046313
# Min iter: 20
# Before adaptation iterations: 19
# Final iterations: 20
# Time taken: 19.278285026550293

# %%
# with obs and path resolution in rrt to be 0.5
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Buckling')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.36532745, 0.91837195]])[0]
time_step = 57

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[1.97400564, 0.39785028]])[0]
print(ref_traj[0], ref_traj[time_step])
rand_area = [[0.0, -1.0], [3.0, 2.0]]
evalObject.reachDestInvRRTPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[1], scaling_factors=[0.02], i_state=[ref_traj[0]], 
                                adaptation_run=True, rand_area=rand_area, n_paths=1)
# Out:
# [0.36532745 0.91837195] [1.01761652 1.39554826]
# [1.97400564 0.39785028] [ 1.65171543 -1.22443925]
# Model file ../../eval/models/model_vp_2_v_Buckling_RBF_1_256_ReLU_supp.h5
# [[array([ 1.65171543, -1.22443925]), array([ 1.64195691, -0.72453448])], [array([ 1.64195691, -0.72453448]), array([ 2.09198699, -0.50665166])], [array([ 2.09198699, -0.50665166]), array([ 2.05847025, -0.00777629])], [array([ 2.05847025, -0.00777629]), array([1.96811999, 0.48399279])], [array([1.96811999, 0.48399279]), array([2.13329628, 0.95592159])], [array([2.13329628, 0.95592159]), array([1.64561626, 1.06623114])], [array([1.64561626, 1.06623114]), array([1.20280629, 1.2984365 ])], [array([1.20280629, 1.2984365 ]), array([1.01761652, 1.39554826])]]
# ***** path idx 0 s_factor 0.02 correction steps 1
# [ 1.65171543 -1.22443925] [ 1.64195691 -0.72453448]
# 500
# Starting distance: 0.5
# Final relative distance 0.0047115088744711315
# Min relative distance 0.0047115088744711315
# Min iter: 29
# Before adaptation iterations: 29
# Final iterations: 29
# ***** path idx 1 s_factor 0.02 correction steps 1
# [ 1.64195691 -0.72453448] [ 2.09198699 -0.50665166]
# 500
# Starting distance: 0.49999999999999994
# Final relative distance 0.007138949444194003
# Min relative distance 0.007138949444194003
# Min iter: 28
# Before adaptation iterations: 28
# Final iterations: 28
# ***** path idx 2 s_factor 0.02 correction steps 1
# [ 2.09198699 -0.50665166] [ 2.05847025 -0.00777629]
# 500
# Starting distance: 0.5
# Final relative distance 0.0013414822121664996
# Min relative distance 0.0013414822121664996
# Min iter: 25
# Before adaptation iterations: 25
# Final iterations: 25
# ***** path idx 3 s_factor 0.02 correction steps 1
# [ 2.05847025 -0.00777629] [1.96811999 0.48399279]
# 500
# Starting distance: 0.5
# Final relative distance 0.015713477695175317
# Min relative distance 0.015713477695175317
# Min iter: 23
# Before adaptation iterations: 23
# Final iterations: 23
# ***** path idx 4 s_factor 0.02 correction steps 1
# [1.96811999 0.48399279] [2.13329628 0.95592159]
# 500
# Starting distance: 0.4999999999999999
# Before adaptation relative distance 0.07044513875622412
# Adaptations reached it's limits
# Final relative distance 0.07522095378904636
# Min relative distance 0.07044513875622412
# Min iter: 28
# Before adaptation iterations: 29
# Final iterations: 30
# ***** path idx 5 s_factor 0.02 correction steps 1
# [2.13329628 0.95592159] [1.64561626 1.06623114]
# 500
# Starting distance: 0.5
# Final relative distance 0.010866701713415798
# Min relative distance 0.010866701713415798
# Min iter: 22
# Before adaptation iterations: 22
# Final iterations: 22
# ***** path idx 6 s_factor 0.02 correction steps 1
# [1.64561626 1.06623114] [1.20280629 1.2984365 ]
# 500
# Starting distance: 0.5
# Final relative distance 0.006127114284792601
# Min relative distance 0.006127114284792601
# Min iter: 24
# Before adaptation iterations: 24
# Final iterations: 24
# ***** path idx 7 s_factor 0.02 correction steps 1
# [1.20280629 1.2984365 ] [1.01761652 1.39554826]
# 500
# Starting distance: 0.2091074949699328
# Final relative distance 0.04032914818836219
# Min relative distance 0.04032914818836219
# Min iter: 11
# Before adaptation iterations: 11
# Final iterations: 11
# Time taken: 11.795928239822388

# %%
# with obs and path resolution in rrt to be 0.2
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Buckling')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.36532745, 0.91837195]])[0]
time_step = 57

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[1.97400564, 0.39785028]])[0]
print(ref_traj[0], ref_traj[time_step])
rand_area = [[0.0, -1.0], [3.0, 2.0]]
evalObject.reachDestInvRRTPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[1], scaling_factors=[0.02], i_state=[ref_traj[0]], 
                                adaptation_run=True, rand_area=rand_area, n_paths=1)
# Out:
# [0.36532745 0.91837195] [1.01761652 1.39554826]
# [1.97400564 0.39785028] [ 1.65171543 -1.22443925]
# Model file ../../eval/models/model_vp_2_v_Buckling_RBF_1_256_ReLU_supp.h5
# [[array([ 1.65171543, -1.22443925]), array([ 1.69921686, -0.82726974])], [array([ 1.69921686, -0.82726974]), array([ 1.58195092, -0.44484498])], [array([ 1.58195092, -0.44484498]), array([ 1.37665939, -0.10154426])], [array([ 1.37665939, -0.10154426]), array([1.28337392, 0.28742595])], [array([1.28337392, 0.28742595]), array([1.05004048, 0.61231902])], [array([1.05004048, 0.61231902]), array([1.01249018, 1.01055258])], [array([1.01249018, 1.01055258]), array([1.01761652, 1.39554826])]]
# ***** path idx 0 s_factor 0.02 correction steps 1
# [ 1.65171543 -1.22443925] [ 1.69921686 -0.82726974]
# 500
# Starting distance: 0.4
# Final relative distance 0.01733576462365881
# Min relative distance 0.01733576462365881
# Min iter: 24
# Before adaptation iterations: 24
# Final iterations: 24
# ***** path idx 1 s_factor 0.02 correction steps 1
# [ 1.69921686 -0.82726974] [ 1.58195092 -0.44484498]
# 500
# Starting distance: 0.3999999999999999
# Final relative distance 0.007690011165445724
# Min relative distance 0.007690011165445724
# Min iter: 21
# Before adaptation iterations: 21
# Final iterations: 21
# ***** path idx 2 s_factor 0.02 correction steps 1
# [ 1.58195092 -0.44484498] [ 1.37665939 -0.10154426]
# 500
# Starting distance: 0.39999999999999997
# Before adaptation relative distance 0.20425456360890554
# Adaptations reached it's limits
# Final relative distance 0.20425540994600555
# Min relative distance 0.20425456360890554
# Min iter: 29
# Before adaptation iterations: 30
# Final iterations: 31
# ***** path idx 3 s_factor 0.02 correction steps 1
# [ 1.37665939 -0.10154426] [1.28337392 0.28742595]
# 500
# Starting distance: 0.3999999999999999
# Before adaptation relative distance 0.14643466505109579
# Adaptations reached it's limits
# Final relative distance 0.14662562101784643
# Min relative distance 0.14643466505109579
# Min iter: 21
# Before adaptation iterations: 22
# Final iterations: 23
# ***** path idx 4 s_factor 0.02 correction steps 1
# [1.28337392 0.28742595] [1.05004048 0.61231902]
# 500
# Starting distance: 0.40000000000000013
# Final relative distance 0.01786381065648704
# Min relative distance 0.01786381065648704
# Min iter: 21
# Before adaptation iterations: 21
# Final iterations: 21
# ***** path idx 5 s_factor 0.02 correction steps 1
# [1.05004048 0.61231902] [1.01249018 1.01055258]
# 500
# Starting distance: 0.4000000000000001
# Final relative distance 0.014186263798037113
# Min relative distance 0.014186263798037113
# Min iter: 21
# Before adaptation iterations: 21
# Final iterations: 21
# ***** path idx 6 s_factor 0.02 correction steps 1
# [1.01249018 1.01055258] [1.01761652 1.39554826]
# 500
# Starting distance: 0.3850298044195734
# Final relative distance 0.013649047456590558
# Min relative distance 0.013649047456590558
# Min iter: 19
# Before adaptation iterations: 19
# Final iterations: 19
# Time taken: 8.969408512115479

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Roesseler')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[1.71042788, 0.5545868, 1.45154215]])[0]
time_step = 65

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[1.96414956, 1.7424974, 1.0493622]])[0]
print(ref_traj[0], ref_traj[time_step])
rand_area = [[-2.0, 1.5, 0.0], [-0.5, 3.0, 0.5]]
evalObject.reachDestInvRRTPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[1], scaling_factors=[0.02], layers=2, i_state=[ref_traj[0]], 
                                adaptation_run=True, rand_area=rand_area, n_paths=1)
# Out:
# [1.71042788 0.5545868  1.45154215] [-0.43687834  1.76738469  0.03640547]
# [1.96414956 1.7424974  1.0493622 ] [-1.65277418  2.63496971  0.0296592 ]
# Model file ../../eval/models/model_vp_2_v_Roesseler_RBF_2_256_ReLU_supp.h5
# [[-2.  -0.5]
#  [ 1.5  3. ]
#  [ 0.   0.5]]
# (-1.652774178327115, 2.634969714563565, 0.029659201004795868) (-0.43687833543557625, 1.7673846902644752, 0.03640546637171857)
# Checking if can connect to goal at 53 samples
# Can connect to goal
# [(-1.652774178327115, 2.634969714563565, 0.029659201004795868), (-2.0, 2.12197287535142, 0.5), (-0.5, 1.6200491461199888, 0.0), (-0.43687833543557625, 1.7673846902644752, 0.03640546637171857)]
# [[array([-1.65277418,  2.63496971,  0.0296592 ]), array([-2.        ,  2.12197288,  0.5       ])], [array([-2.        ,  2.12197288,  0.5       ]), array([-0.5       ,  1.62004915,  0.        ])], [array([-0.5       ,  1.62004915,  0.        ]), array([-0.43687834,  1.76738469,  0.03640547])]]
# ***** path idx 0 s_factor 0.02 correction steps 1
# [-1.65277418  2.63496971  0.0296592 ] [-2.          2.12197288  0.5       ]
# 500
# Starting distance: 0.77778660021725
# Before adaptation relative distance 0.6096013008760011
# Adaptations reached it's limits
# Final relative distance 0.609925821018764
# Min relative distance 0.6096013008760011
# Min iter: 31
# Before adaptation iterations: 32
# Final iterations: 33
# ***** path idx 1 s_factor 0.02 correction steps 1
# [-2.          2.12197288  0.5       ] [-0.5         1.62004915  0.        ]
# 500
# Starting distance: 1.658893435385645
# Before adaptation relative distance 0.025241357517197544
# Adaptations reached it's limits
# Final relative distance 0.02806388066941367
# Min relative distance 0.025241357517197544
# Min iter: 60
# Before adaptation iterations: 61
# Final iterations: 63
# ***** path idx 2 s_factor 0.02 correction steps 1
# [-0.5         1.62004915  0.        ] [-0.43687834  1.76738469  0.03640547]
# 500
# Starting distance: 0.1643699032288997
# Final relative distance 0.056195286215398495
# Min relative distance 0.056195286215398495
# Min iter: 8
# Before adaptation iterations: 8
# Final iterations: 8
# Time taken: 5.115845203399658

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='InputSCancel')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[ 0.19285201, -0.07309636, -0.01151512]])[0]
time_step = 48

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.18057488, 0.39015317, 0.45334272]])[0]
print(ref_traj[0], ref_traj[time_step])
rand_area = [[0.0, 0.0, 0.0], [0.4, 0.4, 0.4]]
evalObject.reachDestInvRRTPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[1], scaling_factors=[0.02], layers=1, i_state=[ref_traj[0]], 
                                adaptation_run=True, neurons=256, rand_area=rand_area, n_paths=1)
# Out:
# [ 0.19285201 -0.07309636 -0.01151512] [ 0.10490641 -0.09601989 -0.08040324]
# [0.18057488 0.39015317 0.45334272] [0.05204434 0.18065012 0.39709286]
# Model file ../../eval/models/model_vp_2_v_InputSCancel_RBF_1_256_ReLU_supp.h5
# [[0.  0.4]
#  [0.  0.4]
#  [0.  0.4]]
# (0.05204433839983228, 0.18065012351657322, 0.3970928605886627) (0.10490640607438503, -0.09601989310936199, -0.0804032416781843)
# Can connect to goal
# [(0.05204433839983228, 0.18065012351657322, 0.3970928605886627), (0.4, 0.4, 0.20919364168640947), (0.0, 0.0, 0.0), (0.10490640607438503, -0.09601989310936199, -0.0804032416781843)]
# [[array([0.05204434, 0.18065012, 0.39709286]), array([0.4       , 0.4       , 0.20919364])], [array([0.4       , 0.4       , 0.20919364]), array([0., 0., 0.])], [array([0., 0., 0.]), array([ 0.10490641, -0.09601989, -0.08040324])]]
# ***** path idx 0 s_factor 0.02 correction steps 1
# [0.05204434 0.18065012 0.39709286] [0.4        0.4        0.20919364]
# 500
# Starting distance: 0.4522097159692413
# Before adaptation relative distance 0.6345210868554583
# Adaptations reached it's limits
# Final relative distance 0.6345269319663518
# Min relative distance 0.6345210868554583
# Min iter: 37
# Before adaptation iterations: 38
# Final iterations: 39
# ***** path idx 1 s_factor 0.02 correction steps 1
# [0.4        0.4        0.20919364] [0. 0. 0.]
# 500
# Starting distance: 0.6031268355180541
# Final relative distance 0.006922769008520536
# Min relative distance 0.006922769008520536
# Min iter: 19
# Before adaptation iterations: 19
# Final iterations: 19
# ***** path idx 2 s_factor 0.02 correction steps 1
# [0. 0. 0.] [ 0.10490641 -0.09601989 -0.08040324]
# 500
# Starting distance: 0.16337030079098705
# Final relative distance 0.044235414813993575
# Min relative distance 0.044235414813993575
# Min iter: 8
# Before adaptation iterations: 8
# Final iterations: 8
# Time taken: 3.60760498046875

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC6')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.38962269, 0.39890181, 0.37068618]])[0]
time_step = 66

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.22604649, 0.22247081, 0.21013492]])[0]
print(ref_traj[0], ref_traj[time_step])
rand_area = [[0.3, 0.0, -1.0], [0.6, 0.1, -0.5]]
evalObject.reachDestInvRRTPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[1], scaling_factors=[0.02], layers=1, i_state=[ref_traj[0]], 
                                adaptation_run=True, neurons=512, rand_area=rand_area, n_paths=1)
# Out:
# [0.38962269 0.39890181 0.37068618] [ 0.53397099  0.10339372 -0.96267678]
# [0.22604649 0.22247081 0.21013492] [ 0.31143462  0.00790191 -0.4917429 ]
# Model file ../../eval/models/model_vp_2_v_OtherBenchC6_RBF_1_512_ReLU_supp.h5
# [[ 0.3  0.6]
#  [ 0.   0.1]
#  [-1.  -0.5]]
# (0.3114346153711803, 0.007901907825220725, -0.4917429042188892) (0.5339709939056274, 0.1033937164148944, -0.9626767807566108)
# Checking if can connect to goal at 39 samples
# Can connect to goal
# [(0.3114346153711803, 0.007901907825220725, -0.4917429042188892), (0.6, 0.1, -1.0), (0.3, 0.0, -0.5), (0.3140793143643436, 0.1, -1.0), (0.6, 0.0, -0.5), (0.5477424595505082, 0.1, -1.0), (0.5339709939056274, 0.1033937164148944, -0.9626767807566108)]
# [[array([ 0.31143462,  0.00790191, -0.4917429 ]), array([ 0.6,  0.1, -1. ])], [array([ 0.6,  0.1, -1. ]), array([ 0.3,  0. , -0.5])], [array([ 0.3,  0. , -0.5]), array([ 0.31407931,  0.1       , -1.        ])], [array([ 0.31407931,  0.1       , -1.        ]), array([ 0.6,  0. , -0.5])], [array([ 0.6,  0. , -0.5]), array([ 0.54774246,  0.1       , -1.        ])], [array([ 0.54774246,  0.1       , -1.        ]), array([ 0.53397099,  0.10339372, -0.96267678])]]
# ***** path idx 0 s_factor 0.02 correction steps 1
# [ 0.31143462  0.00790191 -0.4917429 ] [ 0.6  0.1 -1. ]
# 500
# Starting distance: 0.5916733179720562
# Before adaptation relative distance 0.024505510600511166
# Adaptations reached it's limits
# Final relative distance 0.025304590838078612
# Min relative distance 0.024505510600511166
# Min iter: 31
# Before adaptation iterations: 32
# Final iterations: 34
# ***** path idx 1 s_factor 0.02 correction steps 1
# [ 0.6  0.1 -1. ] [ 0.3  0.  -0.5]
# 500
# Starting distance: 0.5916079783099616
# Before adaptation relative distance 0.06237990207441922
# Adaptations reached it's limits
# Final relative distance 0.06237998037709665
# Min relative distance 0.06237990207441922
# Min iter: 39
# Before adaptation iterations: 40
# Final iterations: 41
# ***** path idx 2 s_factor 0.02 correction steps 1
# [ 0.3  0.  -0.5] [ 0.31407931  0.1        -1.        ]
# 500
# Starting distance: 0.5100962919812003
# Before adaptation relative distance 0.26490732182176857
# Adaptations reached it's limits
# Final relative distance 0.2685025124967224
# Min relative distance 0.26490732182176857
# Min iter: 11
# Before adaptation iterations: 12
# Final iterations: 13
# ***** path idx 3 s_factor 0.02 correction steps 1
# [ 0.31407931  0.1        -1.        ] [ 0.6  0.  -0.5]
# 500
# Starting distance: 0.5845944222059973
# Before adaptation relative distance 0.40380559461633125
# Before adaptation relative distance 0.40380559461633125
# Adaptations reached it's limits
# Final relative distance 0.40380559461633125
# Min relative distance 0.40380559461633125
# Min iter: 16
# Before adaptation iterations: 17
# Final iterations: 19
# ***** path idx 4 s_factor 0.02 correction steps 1
# [ 0.6  0.  -0.5] [ 0.54774246  0.1        -1.        ]
# 500
# Starting distance: 0.5125727758414704
# Final relative distance 0.011583931560823579
# Min relative distance 0.011583931560823579
# Min iter: 13
# Before adaptation iterations: 13
# Final iterations: 13
# ***** path idx 5 s_factor 0.02 correction steps 1
# [ 0.54774246  0.1        -1.        ] [ 0.53397099  0.10339372 -0.96267678]
# 500
# Starting distance: 0.039927349922114205
# Final relative distance 0.18141755905245163
# Min relative distance 0.18141755905245163
# Min iter: 2
# Before adaptation iterations: 2
# Final iterations: 2
# Time taken: 17.040626287460327
