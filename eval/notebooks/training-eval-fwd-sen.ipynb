# %%
# with supp data
import matplotlib
# %matplotlib inline

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from learningModule import DataConfiguration, CreateTrainNN

epochs = 30
dynamics = 'Brussellator'
dataObject = DataConfiguration(dynamics=dynamics, gradient_run=True)
dataObject.setSteps(250)
dataObject.setSamples(50)
dataObject.setLowerBound([0.0, 0.0])
dataObject.setUpperBound([2.0, 2.0])
dataObject.generateTrajectories(scaling=0.01)
dataObject.showTrajectories()
dataObject.createData(jumps=[1,2,4,8,10,12,16])

nnObject1 = CreateTrainNN(dynamics=dynamics, dnn_rbf='RBF')
nnObject1.createInputOutput(data_object = dataObject, inp_vars=['x','xp','v','t'], out_vars=['vp'])
nnObject1.setEpochs(epochs)
nnObject1.trainTestNN(optim='SGD', loss_fn='mae', layers=1, neurons=256)
# Out:
# 10
# (524000, 7)
# (471600, 7)
# (471600, 2)
#
# Setting the activation function to default - ReLU.
#
# Epoch 1/30
# 7369/7369 [==============================] - 14s 2ms/step - loss: 0.0913 - accuracy: 0.9284 - mse: 0.0181
# Epoch 2/30
# 7369/7369 [==============================] - 14s 2ms/step - loss: 0.0600 - accuracy: 0.9507 - mse: 0.0058
# Epoch 3/30
# 7369/7369 [==============================] - 14s 2ms/step - loss: 0.0576 - accuracy: 0.9522 - mse: 0.0053
# Epoch 4/30
# 7369/7369 [==============================] - 13s 2ms/step - loss: 0.0557 - accuracy: 0.9537 - mse: 0.0049
# Epoch 5/30
# 7369/7369 [==============================] - 13s 2ms/step - loss: 0.0557 - accuracy: 0.9531 - mse: 0.0049
# Epoch 6/30
# 7369/7369 [==============================] - 13s 2ms/step - loss: 0.0557 - accuracy: 0.9536 - mse: 0.0049
# Epoch 7/30
# 7369/7369 [==============================] - 14s 2ms/step - loss: 0.0551 - accuracy: 0.9523 - mse: 0.0048
# Epoch 8/30
# ...

# %%
# with supp data
import matplotlib
# %matplotlib inline

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from learningModule import DataConfiguration, CreateTrainNN

epochs = 30
dynamics = 'OtherBenchC1'
dataObject = DataConfiguration(dynamics=dynamics, gradient_run=True)
dataObject.setSteps(200)
dataObject.setSamples(50)
dataObject.setLowerBound([0.5, 0.5])
dataObject.setUpperBound([1.5, 1.5])
dataObject.generateTrajectories(scaling=0.01)
dataObject.showTrajectories()
dataObject.createData(jumps=[1,2,4,8,10,12,16])

nnObject1 = CreateTrainNN(dynamics=dynamics, dnn_rbf='RBF')
nnObject1.createInputOutput(data_object = dataObject, inp_vars=['x','xp','v','t'], out_vars=['vp'])
nnObject1.setEpochs(epochs)
nnObject1.trainTestNN(optim='SGD', loss_fn='mae', layers=1, neurons=512)
# Out:
# 10
# (417000, 7)
# (375300, 7)
# (375300, 2)
#
# Setting the activation function to default - ReLU.
#
# Epoch 1/30
# 5865/5865 [==============================] - 22s 4ms/step - loss: 0.1158 - accuracy: 0.8229 - mse: 0.0417
# Epoch 2/30
# 5865/5865 [==============================] - 23s 4ms/step - loss: 0.0502 - accuracy: 0.8772 - mse: 0.0046
# Epoch 3/30
# 5865/5865 [==============================] - 25s 4ms/step - loss: 0.0409 - accuracy: 0.8868 - mse: 0.0029
# Epoch 4/30
# 5865/5865 [==============================] - 24s 4ms/step - loss: 0.0386 - accuracy: 0.8898 - mse: 0.0026
# Epoch 5/30
# 5865/5865 [==============================] - 23s 4ms/step - loss: 0.0384 - accuracy: 0.8881 - mse: 0.0025
# Epoch 6/30
# 5865/5865 [==============================] - 24s 4ms/step - loss: 0.0380 - accuracy: 0.8892 - mse: 0.0024
# Epoch 7/30
# 5865/5865 [==============================] - 23s 4ms/step - loss: 0.0372 - accuracy: 0.8907 - mse: 0.0024
# Epoch 8/30
# ...

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
evalObject.spaceExploreFwd()
# Out:
# Model file ../../eval/models/model_v_2_vp_Brussellator_RBF_1_256_ReLU.h5
# Done****
# Done****

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
evalObject.spaceExploreFwd()
# Out:
# Model file ../../eval/models/model_v_2_vp_Brussellator_RBF_1_256_ReLU.h5
# Done****
# Done****
# Done****
# Done****
# Done****

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
evalObject.spaceExploreFwd2()
# Out:
# Model file ../../eval/models/model_v_2_vp_Brussellator_RBF_1_256_ReLU.h5
# Done****
# Done****
# Done****
# Done****

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
evalObject.spaceExploreFwd2()
# Out:
# Model file ../../eval/models/model_v_2_vp_Brussellator_RBF_1_256_ReLU.h5
# Done**** 0
# Done**** 1
# Done**** 2
# Done**** 3

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC1')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
evalObject.spaceExploreFwd2()
# Out:
# Model file ../../eval/models/model_v_2_vp_OtherBenchC1_RBF_1_256_ReLU.h5
# Done**** 0
# Done**** 1
# Done**** 2
# Done**** 3

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC1')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
evalObject.spaceExploreFwd2(neurons=512)
# Out:
# Model file ../../eval/models/model_v_2_vp_OtherBenchC1_RBF_1_512_ReLU.h5
# Done**** 0
# Done**** 1
# Done**** 2
# Done**** 3
