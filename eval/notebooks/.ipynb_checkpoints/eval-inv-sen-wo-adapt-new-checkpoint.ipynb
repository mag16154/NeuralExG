# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.62112784, 0.42324306]])[0]
time_step = 111

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[1.83265639, 1.98291256]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[1, 2, 5, 10],
                        scaling_factors=[0.01, 0.05], i_state=[ref_traj[0]], supp=True, adaptation_run=True)
# Out:
# [0.62112784 0.42324306] [0.50012264 1.0692351 ]
# [1.83265639 1.98291256] [1.72268878 0.76117692]
# Model file ../../eval/models/model_vp_2_v_Brussellator_RBF_1_256_ReLU_supp.h5
#  *** Baseline Greedy ***
#
# ***** path idx 0 s_factor 0.01 correction steps 1
# [1.72268878 0.76117692] [0.50012264 1.0692351 ]
# vp direction [-0.01, -0.0]
# 500
# Starting distance: 1.2607806323719486
# Before adaptation relative distance 0.037591547016776146
# Final relative distance 0.007331497642707675
# Min relative distance 0.007331497642707675
# Final dist: 0.009243410234206433
# Min dist: 0.009243410234206433
# Min iter: 71
# Terminating state: [0.67797712 0.39309641]
# Before adaptation iterations: 67
# Final iterations: 71
# Time taken: 2.325714349746704
# ***** path idx 0 s_factor 0.01 correction steps 1
# [1.72268878 0.76117692] [0.50012264 1.0692351 ]
# 500
# Starting distance: 1.2607806323719486
# Final relative distance 0.006107494938221304
# Min relative distance 0.006107494938221304
# Min iter: 68
# Before adaptation iterations: 68
# Final iterations: 68
# Time taken: 1.9404826164245605
# ***** path idx 0 s_factor 0.01 correction steps 2
# Starting distance: 1.2607806323719486
# Final relative distance 0.0010730191679950388
# Min relative distance: 0.0010730191679950388
# Min iter: 40
# Before adaptation iterations: 41
# Final iterations: 41
# Time taken: 2.2422618865966797
# ***** path idx 0 s_factor 0.01 correction steps 5
# Starting distance: 1.2607806323719486
# Final relative distance 0.0021165609547040445
# Min relative distance: 0.0021165609547040445
# Min iter: 19
# Before adaptation iterations: 20
# Final iterations: 20
# Time taken: 2.5300512313842773
# ***** path idx 0 s_factor 0.01 correction steps 10
# Starting distance: 1.2607806323719486
# Final relative distance 0.0054008414317476645
# Min relative distance: 0.0054008414317476645
# Min iter: 11
# Before adaptation iterations: 12
# Final iterations: 12
# Time taken: 2.8285598754882812
#  *** Baseline Greedy ***
#
# ***** path idx 0 s_factor 0.05 correction steps 1
# [1.72268878 0.76117692] [0.50012264 1.0692351 ]
# vp direction [-0.05, -0.0]
# 500
# Starting distance: 1.2607806323719486
# Before adaptation relative distance 0.023171189930119206
# Final relative distance 0.00765251193979317
# Min relative distance 0.00765251193979317
# Final dist: 0.00964813884268632
# Min dist: 0.00964813884268632
# Min iter: 25
# Terminating state: [0.66432806 0.39529076]
# Before adaptation iterations: 23
# Final iterations: 25
# Time taken: 0.8543901443481445
# ***** path idx 0 s_factor 0.05 correction steps 1
# [1.72268878 0.76117692] [0.50012264 1.0692351 ]
# 500
# Starting distance: 1.2607806323719486
# Before adaptation relative distance 0.014096031203294302
# Before adaptation relative distance 0.010643752682612901
# Final relative distance 0.005429830737475863
# Min relative distance 0.005429830737475863
# Min iter: 26
# Before adaptation iterations: 23
# Final iterations: 26
# Time taken: 0.9091637134552002
# ***** path idx 0 s_factor 0.05 correction steps 2
# Starting distance: 1.2607806323719486
# Final relative distance 0.0034100523321835526
# Min relative distance: 0.0034100523321835526
# Min iter: 11
# Before adaptation iterations: 12
# Final iterations: 12
# Time taken: 0.8011152744293213
# ***** path idx 0 s_factor 0.05 correction steps 5
# Starting distance: 1.2607806323719486
# Before adaptation relative distance 0.01696649178462632
# Final relative distance 0.005760086048761254
# Min relative distance: 0.005760086048761254
# Min iter: 8
# Before adaptation iterations: 8
# Final iterations: 9
# Time taken: 0.9238333702087402
# ***** path idx 0 s_factor 0.05 correction steps 10
# Starting distance: 1.2607806323719486
# Before adaptation relative distance 0.01204659941872632
# Final relative distance 0.005259689064511325
# Min relative distance: 0.005259689064511325
# Min iter: 5
# Before adaptation iterations: 5
# Final iterations: 6
# Time taken: 0.8939666748046875

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Vanderpol')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.4378242, 0.66788707]])[0]
time_step = 97

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[1.45506997, 1.87422981]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[1, 2, 5, 10],
                        scaling_factors=[0.01, 0.05], i_state=[ref_traj[0]], supp=True, adaptation_run=True)
# Out:
# [0.4378242  0.66788707] [0.95203302 0.21170201]
# [1.45506997 1.87422981] [ 1.80776127 -0.48363905]
# Model file ../../eval/models/model_vp_2_v_Vanderpol_RBF_1_256_ReLU_supp.h5
#  *** Baseline Greedy ***
#
# ***** path idx 0 s_factor 0.01 correction steps 1
# [ 1.80776127 -0.48363905] [0.95203302 0.21170201]
# vp direction [-0.01, -0.0]
# 500
# Starting distance: 1.1026196278277411
# Before adaptation relative distance 0.009927629906979837
# Final relative distance 0.008202679120467316
# Min relative distance 0.008202679120467316
# Final dist: 0.009044434999000055
# Min dist: 0.009044434999000055
# Min iter: 90
# Terminating state: [0.43770585 0.65984816]
# Before adaptation iterations: 89
# Final iterations: 90
# Time taken: 2.8289906978607178
# ***** path idx 0 s_factor 0.01 correction steps 1
# [ 1.80776127 -0.48363905] [0.95203302 0.21170201]
# 500
# Starting distance: 1.1026196278277411
# Final relative distance 0.0040596288989403284
# Min relative distance 0.0040596288989403284
# Min iter: 71
# Before adaptation iterations: 71
# Final iterations: 71
# Time taken: 2.0361170768737793
# ***** path idx 0 s_factor 0.01 correction steps 2
# Starting distance: 1.1026196278277411
# Final relative distance 0.008256847816940431
# Min relative distance: 0.008256847816940431
# Min iter: 43
# Before adaptation iterations: 44
# Final iterations: 44
# Time taken: 2.341139078140259
# ***** path idx 0 s_factor 0.01 correction steps 5
# Starting distance: 1.1026196278277411
# Final relative distance 0.005623900853156788
# Min relative distance: 0.005623900853156788
# Min iter: 20
# Before adaptation iterations: 21
# Final iterations: 21
# Time taken: 2.5717639923095703
# ***** path idx 0 s_factor 0.01 correction steps 10
# Starting distance: 1.1026196278277411
# Final relative distance 0.007960655178188981
# Min relative distance: 0.007960655178188981
# Min iter: 10
# Before adaptation iterations: 11
# Final iterations: 11
# Time taken: 2.7998831272125244
#  *** Baseline Greedy ***
#
# ***** path idx 0 s_factor 0.05 correction steps 1
# [ 1.80776127 -0.48363905] [0.95203302 0.21170201]
# vp direction [-0.05, -0.0]
# 500
# Starting distance: 1.1026196278277411
# Before adaptation relative distance 0.026270392200264236
# Before adaptation relative distance 0.01595166658914419
# Final relative distance 0.008067931303372775
# Min relative distance 0.008067931303372775
# Final dist: 0.008895859411064673
# Min dist: 0.008895859411064673
# Min iter: 37
# Terminating state: [0.43708616 0.67534262]
# Before adaptation iterations: 33
# Final iterations: 37
# Time taken: 1.1552340984344482
# ***** path idx 0 s_factor 0.05 correction steps 1
# [ 1.80776127 -0.48363905] [0.95203302 0.21170201]
# 500
# Starting distance: 1.1026196278277411
# Final relative distance 0.007563051202418996
# Min relative distance 0.007563051202418996
# Min iter: 23
# Before adaptation iterations: 23
# Final iterations: 23
# Time taken: 0.7895300388336182
# ***** path idx 0 s_factor 0.05 correction steps 2
# Starting distance: 1.1026196278277411
# Before adaptation relative distance 0.020059401119939445
# Final relative distance 0.008977359836841723
# Min relative distance: 0.008977359836841723
# Min iter: 13
# Before adaptation iterations: 13
# Final iterations: 14
# Time taken: 0.8669025897979736
# ***** path idx 0 s_factor 0.05 correction steps 5
# Starting distance: 1.1026196278277411
# Before adaptation relative distance 0.012443472569290945
# Final relative distance 0.004038578760833348
# Min relative distance: 0.004038578760833348
# Min iter: 6
# Before adaptation iterations: 6
# Final iterations: 7
# Time taken: 0.852637767791748
# ***** path idx 0 s_factor 0.05 correction steps 10
# Starting distance: 1.1026196278277411
# Before adaptation relative distance 0.0117372855162708
# Final relative distance 0.0037959580844870383
# Min relative distance: 0.0037959580844870383
# Min iter: 4
# Before adaptation iterations: 4
# Final iterations: 5
# Time taken: 0.8644242286682129
