# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC2')
evalObject.setIterCount(100)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 87

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(samples=1)[0]
print(ref_traj[0], ref_traj[time_step])
rand_area = [[0.0, 3.0], [-0.5, 2.0]]
evalObject.reachDestInvRRTPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.005], i_state=[ref_traj[0]], 
                                adaptation_run=True, rand_area=rand_area, n_paths=2)
# Out:
# [0.80756886 0.96269517] [1.29187819 0.22379422]
# [0.82247556 0.50748026] [ 1.01253714 -0.17194469]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# [[array([ 1.01253714, -0.17194469]), array([0.83158616, 0.18478594])], [array([0.83158616, 0.18478594]), array([1.23015744, 0.21856358])], [array([1.23015744, 0.21856358]), array([1.29187819, 0.22379422])]]
# [[array([ 1.01253714, -0.17194469]), array([0.82870228, 0.18330838])], [array([0.82870228, 0.18330838]), array([1.22718291, 0.21813926])], [array([1.22718291, 0.21813926]), array([1.29187819, 0.22379422])]]
# ***** path idx 0 s_factor 0.005 correction steps 1
# [ 1.01253714 -0.17194469] [0.83158616 0.18478594]
# 100
# Starting distance: 0.4
# Before adaptation relative distance 0.045127290380890576
# Adaptations reached it's limits
# Final relative distance 0.04557765225136771
# Min relative distance 0.045127290380890576
# Min iter: 48
# Before adaptation iterations: 49
# Final iterations: 100
# ...

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC2')
evalObject.setIterCount(100)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 74

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(samples=1)[0]
print(ref_traj[0], ref_traj[time_step])
rand_area = [[0.0, 3.0], [-0.5, 2.5]]
evalObject.reachDestInvRRTPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.005], i_state=[ref_traj[0]], 
                                adaptation_run=True, rand_area=rand_area, n_paths=2)
# Out:
# [0.95789847 0.55127651] [ 1.16876018 -0.08524488]
# [0.50376567 0.8554086 ] [0.90303711 0.36823412]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# [[array([0.90303711, 0.36823412]), array([1.00415001, 0.19567636])], [array([1.00415001, 0.19567636]), array([1.10526292, 0.0231186 ])], [array([1.10526292, 0.0231186 ]), array([ 1.16876018, -0.08524488])]]
# [[array([0.90303711, 0.36823412]), array([1.00415001, 0.19567636])], [array([1.00415001, 0.19567636]), array([1.10526292, 0.0231186 ])], [array([1.10526292, 0.0231186 ]), array([ 1.16876018, -0.08524488])]]
# ***** path idx 0 s_factor 0.005 correction steps 1
# [0.90303711 0.36823412] [1.00415001 0.19567636]
# 100
# Starting distance: 0.2
# Before adaptation relative distance 0.02938399573111355
# Final relative distance 0.017436986901339005
# Min relative distance 0.017436986901339005
# Min iter: 46
# Before adaptation iterations: 45
# Final iterations: 46
# ...

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='SinglePendulum')
evalObject.setIterCount(100)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 53

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(samples=1)[0]
print(ref_traj[0], ref_traj[time_step])
rand_area = [[0.0, 4.0], [-2.0, 2.0]]
evalObject.reachDestInvRRTPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.005], i_state=[ref_traj[0]], 
                                adaptation_run=True, rand_area=rand_area, n_paths=2)
# Out:
# [1.27480332 0.45231103] [ 1.10723623 -0.6420998 ]
# [1.71166931 0.54158265] [ 1.43907494 -0.95053166]
# Model file ../../eval-cav/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# [[array([ 1.43907494, -0.95053166]), array([ 1.33539449, -0.77950428])], [array([ 1.33539449, -0.77950428]), array([ 1.2775426 , -0.58805413])], [array([ 1.2775426 , -0.58805413]), array([ 1.10723623, -0.6420998 ])]]
# [[array([ 1.43907494, -0.95053166]), array([ 1.2925814, -0.8143713])], [array([ 1.2925814, -0.8143713]), array([ 1.16533806, -0.66006922])], [array([ 1.16533806, -0.66006922]), array([ 1.10723623, -0.6420998 ])]]
# ***** path idx 0 s_factor 0.005 correction steps 1
# [ 1.43907494 -0.95053166] [ 1.33539449 -0.77950428]
# 100
# Starting distance: 0.19999999999999998
# Final relative distance 0.010316469196049198
# Min relative distance 0.010316469196049198
# Min iter: 31
# Before adaptation iterations: 31
# Final iterations: 31
# ***** path idx 1 s_factor 0.005 correction steps 1
# ...

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC5')
evalObject.setIterCount(100)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 63

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(samples=1)[0]
print(ref_traj[0], ref_traj[time_step])
rand_area = [[0.1, 0.0, 0.1], [0.2, 0.1, 0.2]]
evalObject.reachDestInvRRTPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.005], i_state=[ref_traj[0]], 
                                adaptation_run=True, rand_area=rand_area, n_paths=2)
# Out:
# [0.49025754 0.31947604 0.37889334] [ 0.1820459  -0.01732112  0.20250236]
# [0.22437451 0.41077352 0.41410767] [0.13725239 0.12132531 0.11151782]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# [[0.1 0.2]
#  [0.  0.1]
#  [0.1 0.2]]
# (0.13725238763234443, 0.12132531313762858, 0.11151781696987546) (0.18204590113348643, -0.017321117858256314, 0.20250235709366726)
# Checking if can connect to goal at 5 samples
# Can connect to goal
# [(0.13725238763234443, 0.12132531313762858, 0.11151781696987546), (0.1, 0.0, 0.2), (0.18204590113348643, -0.017321117858256314, 0.20250235709366726)]
# 3
# [[array([0.13725239, 0.12132531, 0.11151782]), array([0.1, 0. , 0.2])], [array([0.1, 0. , 0.2]), array([ 0.1820459 , -0.01732112,  0.20250236])]]
# [[0.1 0.2]
#  [0.  0.1]
#  [0.1 0.2]]
# (0.13725238763234443, 0.12132531313762858, 0.11151781696987546) (0.18204590113348643, -0.017321117858256314, 0.20250235709366726)
# Checking if can connect to goal at 23 samples
# ...

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC5')
evalObject.setIterCount(100)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 63

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(samples=1)[0]
print(ref_traj[0], ref_traj[time_step])
rand_area = [[0.1, 0.0, 0.1], [0.2, 0.1, 0.2]]
evalObject.reachDestInvRRTPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.005], i_state=[ref_traj[0]], 
                                adaptation_run=True, rand_area=rand_area, n_paths=2)
# Out:
# [0.47035746 0.45664812 0.42601279] [0.21424023 0.04718965 0.19873635]
# [0.25356911 0.20959926 0.40719812] [0.07915766 0.02839434 0.12124879]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# [[0.1 0.2]
#  [0.  0.1]
#  [0.1 0.2]]
# (0.0791576590781744, 0.028394339031344026, 0.1212487860603852) (0.2142402344499925, 0.04718965005986756, 0.1987363505953809)
# Can connect to goal
# [(0.0791576590781744, 0.028394339031344026, 0.1212487860603852), (0.2, 0.047374654036642976, 0.2), (0.2142402344499925, 0.04718965005986756, 0.1987363505953809)]
# 3
# [[array([0.07915766, 0.02839434, 0.12124879]), array([0.2       , 0.04737465, 0.2       ])], [array([0.2       , 0.04737465, 0.2       ]), array([0.21424023, 0.04718965, 0.19873635])]]
# [[0.1 0.2]
#  [0.  0.1]
#  [0.1 0.2]]
# (0.0791576590781744, 0.028394339031344026, 0.1212487860603852) (0.2142402344499925, 0.04718965005986756, 0.1987363505953809)
# Checking if can connect to goal at 81 samples
# ...
