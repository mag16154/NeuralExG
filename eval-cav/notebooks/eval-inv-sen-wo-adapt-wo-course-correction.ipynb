# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC1')
evalObject.setIterCount(2000)
dataObject = evalObject.setDataObject()
# dest_traj = dataObject.generateTrajectories(r_states=[[0.52645693, 0.55992238]])[0]
dest_traj = dataObject.generateTrajectories(r_states=[[1.33236118, 1.17698394]])[0]
time_step = 77 # 57

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
# ref_traj = dataObject.generateTrajectories(r_states=[[1.08411932, 0.61952081]])[0]
ref_traj = dataObject.generateTrajectories(r_states=[[0.67184992,1.04788799]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1],  scaling_factors=[0.001, 0.005, 0.01, 0.02], 
                             i_state=[ref_traj[0]], layers=1, neurons=512, adaptation_run=False)
# Out:
# [1.33236118 1.17698394] [ 0.42324177 -1.1718629 ]
# [0.67184992 1.04788799] [ 0.27291516 -0.86687264]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 0.27291516 -0.86687264] [ 0.42324177 -1.1718629 ]
# 2000
# Starting distance: 0.34002521578931083
# Final relative distance 0.011837992014665434
# Min relative distance 0.011837992014665434
# Min iter: 336
# Before adaptation iterations: 336
# Final iterations: 336
# Time taken: 9.34977102279663
# ***** path idx 0 s_factor 0.005 correction steps 1
# [ 0.27291516 -0.86687264] [ 0.42324177 -1.1718629 ]
# 2000
# Starting distance: 0.34002521578931083
# Final relative distance 7.415858629948207e-05
# Min relative distance 7.415858629948207e-05
# Min iter: 68
# Before adaptation iterations: 68
# Final iterations: 68
# Time taken: 1.979743242263794
# ***** path idx 0 s_factor 0.01 correction steps 1
# [ 0.27291516 -0.86687264] [ 0.42324177 -1.1718629 ]
# 2000
# Starting distance: 0.34002521578931083
# Final relative distance 7.415858630358224e-05
# Min relative distance 7.415858630358224e-05
# Min iter: 34
# Before adaptation iterations: 34
# Final iterations: 34
# Time taken: 1.1180315017700195
# ***** path idx 0 s_factor 0.02 correction steps 1
# [ 0.27291516 -0.86687264] [ 0.42324177 -1.1718629 ]
# 2000
# Starting distance: 0.34002521578931083
# Final relative distance 7.415858630709668e-05
# Min relative distance 7.415858630709668e-05
# Min iter: 17
# Before adaptation iterations: 17
# Final iterations: 17
# Time taken: 0.6603591442108154

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC2')
evalObject.setIterCount(2000)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.74224485, 1.1416229]])[0]
time_step = 189

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[1.11786202, 1.18747043]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.001, 0.005, 0.01, 0.02], 
                             i_state=[ref_traj[0]], layers=1, neurons=512, adaptation_run=False)
# Out:
# [0.74224485 1.1416229 ] [ 0.99202868 -0.5327984 ]
# [1.11786202 1.18747043] [ 1.38330558 -0.61235932]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 1.38330558 -0.61235932] [ 0.99202868 -0.5327984 ]
# 2000
# Starting distance: 0.39928379564010535
# Final relative distance 0.010728698952577803
# Min relative distance 0.010728698952577803
# Min iter: 395
# Before adaptation iterations: 395
# Final iterations: 395
# Time taken: 10.839019775390625
# ***** path idx 0 s_factor 0.005 correction steps 1
# [ 1.38330558 -0.61235932] [ 0.99202868 -0.5327984 ]
# 2000
# Starting distance: 0.39928379564010535
# Final relative distance 0.010728698952671572
# Min relative distance 0.010728698952671572
# Min iter: 79
# Before adaptation iterations: 79
# Final iterations: 79
# Time taken: 2.72822642326355
# ***** path idx 0 s_factor 0.01 correction steps 1
# [ 1.38330558 -0.61235932] [ 0.99202868 -0.5327984 ]
# 2000
# Starting distance: 0.39928379564010535
# Final relative distance 0.0017937225795750357
# Min relative distance 0.0017937225795750357
# Min iter: 40
# Before adaptation iterations: 40
# Final iterations: 40
# Time taken: 1.5781536102294922
# ***** path idx 0 s_factor 0.02 correction steps 1
# [ 1.38330558 -0.61235932] [ 0.99202868 -0.5327984 ]
# 2000
# Starting distance: 0.39928379564010535
# Final relative distance 0.0017937225795644092
# Min relative distance 0.0017937225795644092
# Min iter: 20
# Before adaptation iterations: 20
# Final iterations: 20
# Time taken: 1.0442769527435303

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC3')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[1.03690469, 0.71034844]])[0]
time_step = 55

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.62426625, 1.1410296]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.001, 0.005, 0.01, 0.02], i_state=[ref_traj[0]],
                             layers=1, neurons=512, adaptation_run=False)
# Out:
# [1.03690469 0.71034844] [0.56601351 0.00166749]
# [0.62426625 1.1410296 ] [0.33858231 0.21339185]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 1
# [0.33858231 0.21339185] [0.56601351 0.00166749]
# 500
# Starting distance: 0.3107284256691441
# Final relative distance 0.015217229189655285
# Min relative distance 0.015217229189655285
# Min iter: 306
# Before adaptation iterations: 306
# Final iterations: 306
# Time taken: 16.837613105773926
# ***** path idx 0 s_factor 0.005 correction steps 1
# [0.33858231 0.21339185] [0.56601351 0.00166749]
# 500
# Starting distance: 0.3107284256691441
# Final relative distance 0.002344251793428946
# Min relative distance 0.002344251793428946
# Min iter: 62
# Before adaptation iterations: 62
# Final iterations: 62
# Time taken: 3.576038122177124
# ***** path idx 0 s_factor 0.01 correction steps 1
# [0.33858231 0.21339185] [0.56601351 0.00166749]
# 500
# Starting distance: 0.3107284256691441
# Final relative distance 0.002344251793428462
# Min relative distance 0.002344251793428462
# Min iter: 31
# Before adaptation iterations: 31
# Final iterations: 31
# Time taken: 1.945310354232788
# ***** path idx 0 s_factor 0.02 correction steps 1
# [0.33858231 0.21339185] [0.56601351 0.00166749]
# 500
# Starting distance: 0.3107284256691441
# Final relative distance 31.182443490534343
# Min relative distance 0.029838191697106695
# Min iter: 16
# Before adaptation iterations: 500
# Final iterations: 500
# Time taken: 27.135117292404175

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC3')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[1.03690469, 0.71034844]])[0]
time_step = 55

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.62426625, 1.1410296]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[4], scaling_factors=[0.01, 0.02], i_state=[ref_traj[0]],
                             layers=1, neurons=512, adaptation_run=False)
# Out:
# [1.03690469 0.71034844] [0.56601351 0.00166749]
# [0.62426625 1.1410296 ] [0.33858231 0.21339185]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.01 correction steps 4
# Starting distance: 0.3107284256691441
# Final relative distance 0.01048313257054915
# Min relative distance: 0.01048313257054915
# Min iter: 9
# Final dist: 0.003257407279727665
# Before adaptation iterations: 10
# Final iterations: 10
# Time taken: 1.386887550354004
# ***** path idx 0 s_factor 0.02 correction steps 4
# Starting distance: 0.3107284256691441
# Final relative distance 0.011948842153566293
# Min relative distance: 0.011948842153566293
# Min iter: 5
# Final dist: 0.0037128449109467597
# Before adaptation iterations: 6
# Final iterations: 6
# Time taken: 0.8064720630645752

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='SinglePendulum')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[1.86604794, 0.67884024]])[0]
time_step = 79

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[1.28034351, 0.78616977]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[1], scaling_factors=[0.001, 0.005, 0.01, 0.02], 
                             i_state=[ref_traj[0]], layers=1, neurons=512, adaptation_run=False)
# Out:
# [1.86604794 0.67884024] [ 1.28632565 -1.04660113]
# [1.28034351 0.78616977] [ 0.99044709 -0.68250855]
# Model file ../../eval-cav/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 0.99044709 -0.68250855] [ 1.28632565 -1.04660113]
# 500
# Starting distance: 0.4691561846632313
# 460
# Final relative distance 0.01951628255693191
# Min relative distance 0.01951628255693191
# Min iter: 460
# Before adaptation iterations: 460
# Final iterations: 460
# Time taken: 12.97339916229248
# ***** path idx 0 s_factor 0.005 correction steps 1
# [ 0.99044709 -0.68250855] [ 1.28632565 -1.04660113]
# 500
# Starting distance: 0.4691561846632313
# 92
# Final relative distance 0.01951628255695124
# Min relative distance 0.01951628255695124
# Min iter: 92
# Before adaptation iterations: 92
# Final iterations: 92
# Time taken: 2.7539851665496826
# ***** path idx 0 s_factor 0.01 correction steps 1
# [ 0.99044709 -0.68250855] [ 1.28632565 -1.04660113]
# 500
# Starting distance: 0.4691561846632313
# 46
# Final relative distance 0.019516282556957032
# Min relative distance 0.019516282556957032
# Min iter: 46
# Before adaptation iterations: 46
# Final iterations: 46
# Time taken: 1.4511032104492188
# ***** path idx 0 s_factor 0.02 correction steps 1
# [ 0.99044709 -0.68250855] [ 1.28632565 -1.04660113]
# 500
# Starting distance: 0.4691561846632313
# 23
# Final relative distance 0.019516282556955932
# Min relative distance 0.019516282556955932
# Min iter: 23
# Before adaptation iterations: 23
# Final iterations: 23
# Time taken: 0.8256003856658936

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC4')
evalObject.setIterCount(700)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.38340857, 0.55669372, 0.58930397]])[0]
time_step = 159

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.32206212, 0.34180113, 0.37530616]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.001, 0.005, 0.01, 0.02], 
                             i_state=[ref_traj[0]], layers=1, neurons=512, adaptation_run=False)
# Out:
# [0.38340857 0.55669372 0.58930397] [ 1.03913978 -0.64039672 -0.39003155]
# [0.32206212 0.34180113 0.37530616] [ 0.55845796 -0.46497757 -0.22423766]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 0.55845796 -0.46497757 -0.22423766] [ 1.03913978 -0.64039672 -0.39003155]
# 700
# Starting distance: 0.53787963578753
# Final relative distance 0.009071984627853396
# Min relative distance 0.009071984627853396
# Min iter: 533
# Before adaptation iterations: 533
# Final iterations: 533
# Time taken: 15.676033973693848
# ***** path idx 0 s_factor 0.005 correction steps 1
# [ 0.55845796 -0.46497757 -0.22423766] [ 1.03913978 -0.64039672 -0.39003155]
# 700
# Starting distance: 0.53787963578753
# Final relative distance 0.005353680630264022
# Min relative distance 0.005353680630264022
# Min iter: 107
# Before adaptation iterations: 107
# Final iterations: 107
# Time taken: 3.56880259513855
# ***** path idx 0 s_factor 0.01 correction steps 1
# [ 0.55845796 -0.46497757 -0.22423766] [ 1.03913978 -0.64039672 -0.39003155]
# 700
# Starting distance: 0.53787963578753
# Final relative distance 0.003942079363849545
# Min relative distance 0.003942079363849545
# Min iter: 54
# Before adaptation iterations: 54
# Final iterations: 54
# Time taken: 2.139281988143921
# ***** path idx 0 s_factor 0.02 correction steps 1
# [ 0.55845796 -0.46497757 -0.22423766] [ 1.03913978 -0.64039672 -0.39003155]
# 700
# Starting distance: 0.53787963578753
# Final relative distance 0.003942079363842906
# Min relative distance 0.003942079363842906
# Min iter: 27
# Before adaptation iterations: 27
# Final iterations: 27
# Time taken: 1.2747609615325928

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC5')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.2171911, 0.49808728, 0.29292438]])[0]
time_step = 70

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.39171516, 0.22447754, 0.33403873]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.001, 0.005, 0.01, 0.02], 
                             i_state=[ref_traj[0]], layers=1, neurons=512, adaptation_run=False)
# Out:
# [0.2171911  0.49808728 0.29292438] [0.17578161 0.13042461 0.09736385]
# [0.39171516 0.22447754 0.33403873] [ 0.11218481 -0.02772643  0.15109054]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 0.11218481 -0.02772643  0.15109054] [0.17578161 0.13042461 0.09736385]
# 500
# Starting distance: 0.17872566290585679
# Final relative distance 0.02644087496458356
# Min relative distance 0.02644087496458356
# Min iter: 174
# Before adaptation iterations: 174
# Final iterations: 174
# Time taken: 5.323080778121948
# ***** path idx 0 s_factor 0.005 correction steps 1
# [ 0.11218481 -0.02772643  0.15109054] [0.17578161 0.13042461 0.09736385]
# 500
# Starting distance: 0.17872566290585679
# Final relative distance 0.020845707579326595
# Min relative distance 0.020845707579326595
# Min iter: 35
# Before adaptation iterations: 35
# Final iterations: 35
# Time taken: 1.466890811920166
# ***** path idx 0 s_factor 0.01 correction steps 1
# [ 0.11218481 -0.02772643  0.15109054] [0.17578161 0.13042461 0.09736385]
# 500
# Starting distance: 0.17872566290585679
# Final relative distance 0.007130129346978109
# Min relative distance 0.007130129346978109
# Min iter: 18
# Before adaptation iterations: 18
# Final iterations: 18
# Time taken: 1.0144309997558594
# ***** path idx 0 s_factor 0.02 correction steps 1
# [ 0.11218481 -0.02772643  0.15109054] [0.17578161 0.13042461 0.09736385]
# 500
# Starting distance: 0.17872566290585679
# Final relative distance 0.007130129346978447
# Min relative distance 0.007130129346978447
# Min iter: 9
# Before adaptation iterations: 9
# Final iterations: 9
# Time taken: 0.7585117816925049

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC6')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.24799654, 0.20079748, 0.38178508]])[0]
time_step = 128

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.4823449, 0.4482593, 0.3137772]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.001, 0.005, 0.01, 0.02], 
                             i_state=[ref_traj[0]], layers=1, neurons=512, adaptation_run=False)
# Out:
# [0.24799654 0.20079748 0.38178508] [ 0.25254538 -0.19089496 -0.12486461]
# [0.4823449 0.4482593 0.3137772] [ 0.41057508 -0.35322023 -0.28946598]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC6_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 0.41057508 -0.35322023 -0.28946598] [ 0.25254538 -0.19089496 -0.12486461]
# 500
# Starting distance: 0.2800294451090363
# Final relative distance 0.014389362188206438
# Min relative distance 0.014389362188206438
# Min iter: 276
# Before adaptation iterations: 276
# Final iterations: 276
# Time taken: 7.922276973724365
# ***** path idx 0 s_factor 0.005 correction steps 1
# [ 0.41057508 -0.35322023 -0.28946598] [ 0.25254538 -0.19089496 -0.12486461]
# 500
# Starting distance: 0.2800294451090363
# Final relative distance 0.00010515004600421705
# Min relative distance 0.00010515004600421705
# Min iter: 56
# Before adaptation iterations: 56
# Final iterations: 56
# Time taken: 1.8259193897247314
# ***** path idx 0 s_factor 0.01 correction steps 1
# [ 0.41057508 -0.35322023 -0.28946598] [ 0.25254538 -0.19089496 -0.12486461]
# 500
# Starting distance: 0.2800294451090363
# Final relative distance 0.00010515004600573277
# Min relative distance 0.00010515004600573277
# Min iter: 28
# Before adaptation iterations: 28
# Final iterations: 28
# Time taken: 1.0475802421569824
# ***** path idx 0 s_factor 0.02 correction steps 1
# [ 0.41057508 -0.35322023 -0.28946598] [ 0.25254538 -0.19089496 -0.12486461]
# 500
# Starting distance: 0.2800294451090363
# Final relative distance 0.00010515004600663376
# Min relative distance 0.00010515004600663376
# Min iter: 14
# Before adaptation iterations: 14
# Final iterations: 14
# Time taken: 0.60675048828125

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC7')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dataObject.setSteps(150)
# dest_traj = dataObject.generateTrajectories(samples=1)[0]
dest_traj = dataObject.generateTrajectories(r_states=[[0.37993803,0.2731856,0.36936488]])[0]
time_step = 117

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
# ref_traj = dataObject.generateTrajectories(samples=1)[0]
ref_traj = dataObject.generateTrajectories(r_states=[[0.29596794,0.42394008,0.49483644]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.001, 0.005, 0.01, 0.02], 
                             i_state=[ref_traj[0]], layers=1, neurons=512, adaptation_run=False)
# Out:
# [0.37993803 0.2731856  0.36936488] [ 0.03545953  0.19597451 -0.24987798]
# [0.29596794 0.42394008 0.49483644] [-0.20891249  0.2384528  -0.41090296]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC7_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 1
# [-0.20891249  0.2384528  -0.41090296] [ 0.03545953  0.19597451 -0.24987798]
# 500
# Starting distance: 0.2957213813056442
# Final relative distance 0.015965640647278852
# Min relative distance 0.015965640647278852
# Min iter: 291
# Before adaptation iterations: 291
# Final iterations: 291
# Time taken: 12.197085618972778
# ***** path idx 0 s_factor 0.005 correction steps 1
# [-0.20891249  0.2384528  -0.41090296] [ 0.03545953  0.19597451 -0.24987798]
# 500
# Starting distance: 0.2957213813056442
# Final relative distance 0.0024393951579003504
# Min relative distance 0.0024393951579003504
# Min iter: 59
# Before adaptation iterations: 59
# Final iterations: 59
# Time taken: 5.672956943511963
# ***** path idx 0 s_factor 0.01 correction steps 1
# [-0.20891249  0.2384528  -0.41090296] [ 0.03545953  0.19597451 -0.24987798]
# 500
# Starting distance: 0.2957213813056442
# Final relative distance 0.0144684117038321
# Min relative distance 0.0144684117038321
# Min iter: 30
# Before adaptation iterations: 30
# Final iterations: 30
# Time taken: 4.863844394683838
# ***** path idx 0 s_factor 0.02 correction steps 1
# [-0.20891249  0.2384528  -0.41090296] [ 0.03545953  0.19597451 -0.24987798]
# 500
# Starting distance: 0.2957213813056442
# Final relative distance 0.014468411703832165
# Min relative distance 0.014468411703832165
# Min iter: 15
# Before adaptation iterations: 15
# Final iterations: 15
# Time taken: 4.054457187652588

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC8')
evalObject.setIterCount(1000)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.32012507, 0.23593369, 0.3696329, 0.17607225]])[0]
# dest_traj = dataObject.generateTrajectories(r_states=[[0.32519139, 0.14545048, 0.26428496, 0.19935432]])[0]
time_step = 199

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.12190108, 0.32483265, 0.13287113, 0.36699083]])[0]
# ref_traj = dataObject.generateTrajectories(r_states=[[0.31122363, 0.14498294, 0.3924451, 0.27579288]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.001, 0.005, 0.01], 
                             i_state=[ref_traj[0]], layers=1, neurons=512, adaptation_run=False)
# Out:
# [0.32012507 0.23593369 0.3696329  0.17607225] [-0.07120326  1.07825729  0.05393759  0.61884466]
# [0.12190108 0.32483265 0.13287113 0.36699083] [-0.14528703  0.46928619 -0.03024821  0.24007584]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC8_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 1
# [-0.14528703  0.46928619 -0.03024821  0.24007584] [-0.07120326  1.07825729  0.05393759  0.61884466]
# 1000
# Starting distance: 0.7258700090908433
# Final relative distance 0.0067092027909107545
# Min relative distance 0.0067092027909107545
# Min iter: 721
# Before adaptation iterations: 721
# Final iterations: 721
# Time taken: 24.250699996948242
# ***** path idx 0 s_factor 0.005 correction steps 1
# [-0.14528703  0.46928619 -0.03024821  0.24007584] [-0.07120326  1.07825729  0.05393759  0.61884466]
# 1000
# Starting distance: 0.7258700090908433
# Final relative distance 0.0011985742349889098
# Min relative distance 0.0011985742349889098
# Min iter: 145
# Before adaptation iterations: 145
# Final iterations: 145
# Time taken: 5.032914161682129
# ***** path idx 0 s_factor 0.01 correction steps 1
# [-0.14528703  0.46928619 -0.03024821  0.24007584] [-0.07120326  1.07825729  0.05393759  0.61884466]
# 1000
# Starting distance: 0.7258700090908433
# Final relative distance 0.005689711459949146
# Min relative distance 0.005689711459949146
# Min iter: 73
# Before adaptation iterations: 73
# Final iterations: 73
# Time taken: 2.8982534408569336

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC9')
evalObject.setIterCount(1000)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[ 0.53432163, -0.50705631, -0.10642957, 0.90469208]])[0]
time_step = 137

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[ 0.9510333, -0.98411012, -0.29126114, 0.78761868]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.001, 0.005, 0.01, 0.02], 
                             i_state=[ref_traj[0]], layers=1, neurons=512, adaptation_run=False)
# Out:
# [ 0.53432163 -0.50705631 -0.10642957  0.90469208] [-0.37514098 -0.59557826  0.3537923  -0.24489613]
# [ 0.9510333  -0.98411012 -0.29126114  0.78761868] [-0.7722247  -1.10825965  0.45219003  0.34791415]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC9_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 1
# [-0.7722247  -1.10825965  0.45219003  0.34791415] [-0.37514098 -0.59557826  0.3537923  -0.24489613]
# 1000
# Starting distance: 0.8840949278828819
# Final relative distance 0.004631773980094557
# Min relative distance 0.004631773980094557
# Min iter: 880
# Before adaptation iterations: 880
# Final iterations: 880
# Time taken: 30.054877281188965
# ***** path idx 0 s_factor 0.005 correction steps 1
# [-0.7722247  -1.10825965  0.45219003  0.34791415] [-0.37514098 -0.59557826  0.3537923  -0.24489613]
# 1000
# Starting distance: 0.8840949278828819
# Final relative distance 0.0046317739800720336
# Min relative distance 0.0046317739800720336
# Min iter: 176
# Before adaptation iterations: 176
# Final iterations: 176
# Time taken: 7.5147974491119385
# ***** path idx 0 s_factor 0.01 correction steps 1
# [-0.7722247  -1.10825965  0.45219003  0.34791415] [-0.37514098 -0.59557826  0.3537923  -0.24489613]
# 1000
# Starting distance: 0.8840949278828819
# Final relative distance 0.004631773980075322
# Min relative distance 0.004631773980075322
# Min iter: 88
# Before adaptation iterations: 88
# Final iterations: 88
# Time taken: 4.948444604873657
# ***** path idx 0 s_factor 0.02 correction steps 1
# [-0.7722247  -1.10825965  0.45219003  0.34791415] [-0.37514098 -0.59557826  0.3537923  -0.24489613]
# 1000
# Starting distance: 0.8840949278828819
# Final relative distance 0.004631773980072402
# Min relative distance 0.004631773980072402
# Min iter: 44
# Before adaptation iterations: 44
# Final iterations: 44
# Time taken: 3.3085312843322754

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC9Sigmoid')
evalObject.setIterCount(1000)
dataObject = evalObject.setDataObject()
dataObject.setSteps(200)
dest_traj = dataObject.generateTrajectories(r_states=[[-0.93061055, -0.50516322, 0.46661147, -0.49595134]])[0]
time_step = 165

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[-0.9729112, -0.1072407, 0.28281309, -0.08520518]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[50], scaling_factors=[0.001, 0.005, 0.01], 
                             i_state=[ref_traj[0]], layers=1, neurons=512, adaptation_run=False, act_fn='Sigmoid')
# Out:
# [-0.93061055 -0.50516322  0.46661147 -0.49595134] [-0.39951305  0.99052087  0.27540891  0.26624766]
# [-0.9729112  -0.1072407   0.28281309 -0.08520518] [0.00676568 1.02437507 0.75491159 0.65960279]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC9Sigmoid_RBF_1_512_Sigmoid.h5
# ***** path idx 0 s_factor 0.001 correction steps 50
# Starting distance: 0.7421991562553737
# Final relative distance 0.004410983714590916
# Min relative distance: 0.004410983714590916
# Min iter: 10
# Final dist: 0.003273828391225572
# Before adaptation iterations: 11
# Final iterations: 11
# Time taken: 12.831570863723755
# ***** path idx 0 s_factor 0.005 correction steps 50
# Starting distance: 0.7421991562553737
# Final relative distance 0.00019562201111201748
# Min relative distance: 0.00019562201111201748
# Min iter: 4
# Final dist: 0.0001451904915923187
# Before adaptation iterations: 5
# Final iterations: 5
# Time taken: 4.318738222122192
# ***** path idx 0 s_factor 0.01 correction steps 50
# Starting distance: 0.7421991562553737
# Final relative distance 0.0027411831730197213
# Min relative distance: 0.0027411831730197213
# Min iter: 3
# Final dist: 0.002034503838156665
# Before adaptation iterations: 4
# Final iterations: 4
# Time taken: 2.7627158164978027

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OtherBenchC9Tanh')
evalObject.setIterCount(1100)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[-0.64343721, -0.35481454, 0.31645362, -0.48215772]])[0]
time_step = 203

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[-0.94942456, -0.59297976, 0.20508661, -0.20818601]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.001, 0.005, 0.01], 
                             i_state=[ref_traj[0]], layers=1, neurons=512, adaptation_run=False)
# Out:
# [-0.64343721 -0.35481454  0.31645362 -0.48215772] [-0.04216236  0.6936389  -0.66770454 -0.46109881]
# [-0.94942456 -0.59297976  0.20508661 -0.20818601] [-0.10755603  1.09760691 -0.29384613 -0.25453548]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC9Tanh_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 1
# [-0.10755603  1.09760691 -0.29384613 -0.25453548] [-0.04216236  0.6936389  -0.66770454 -0.46109881]
# 1100
# Starting distance: 0.5915276856578584
# Final relative distance 0.007654224422061969
# Min relative distance 0.007654224422061969
# Min iter: 587
# Before adaptation iterations: 587
# Final iterations: 587
# Time taken: 56.938488483428955
# ***** path idx 0 s_factor 0.005 correction steps 1
# [-0.10755603  1.09760691 -0.29384613 -0.25453548] [-0.04216236  0.6936389  -0.66770454 -0.46109881]
# 1100
# Starting distance: 0.5915276856578584
# Final relative distance 0.0025826105774926908
# Min relative distance 0.0025826105774926908
# Min iter: 118
# Before adaptation iterations: 118
# Final iterations: 118
# Time taken: 11.810113191604614
# ***** path idx 0 s_factor 0.01 correction steps 1
# [-0.10755603  1.09760691 -0.29384613 -0.25453548] [-0.04216236  0.6936389  -0.66770454 -0.46109881]
# 1100
# Starting distance: 0.5915276856578584
# Final relative distance 0.002582610577488856
# Min relative distance 0.002582610577488856
# Min iter: 59
# Before adaptation iterations: 59
# Final iterations: 59
# Time taken: 6.003781318664551
