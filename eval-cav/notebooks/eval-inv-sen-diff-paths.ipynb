# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='SinglePendulum')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 70

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(samples=1)[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[2], scaling_factors=[0.001], 
                             i_state=[ref_traj[0]], adaptation_run=True)
ref_traj = dataObject.generateTrajectories(samples=1)[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[2], scaling_factors=[0.001], 
                             i_state=[ref_traj[0]], adaptation_run=True)
# Out:
# [1.56168511 0.98691198] [ 1.25651808 -0.88485945]
# [1.91821147 0.0479211 ] [ 1.31142075 -1.06953193]
# Model file ../../eval-cav/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 2
# Starting distance: 0.19266091491531637
# Final relative distance 0.04754625285538575
# Min relative distance: 0.04754625285538575
# Min iter: 37
# Final dist: 0.009160304575913592
# Before adaptation iterations: 38
# Final iterations: 38
# Time taken: 3.672935962677002
# [1.2255482  0.10930529] [ 0.90649883 -0.61806135]
# Model file ../../eval-cav/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 2
# Starting distance: 0.4401075938650503
# Final relative distance 0.017108582291195617
# Min relative distance: 0.017108582291195617
# Min iter: 57
# Final dist: 0.007529616986620312
# Before adaptation iterations: 58
# Final iterations: 58
# Time taken: 5.509119272232056

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC5')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 81

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(samples=1)[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[2], scaling_factors=[0.001], 
                             i_state=[ref_traj[0]], adaptation_run=True)
ref_traj = dataObject.generateTrajectories(samples=1)[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[2], scaling_factors=[0.001], 
                             i_state=[ref_traj[0]], adaptation_run=True)
# Out:
# [0.21166134 0.4764132  0.25375678] [0.15778712 0.09092551 0.09087482]
# [0.35856459 0.3396247  0.39826815] [0.10902012 0.0109487  0.12627592]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 2
# Starting distance: 0.10013864592692337
# Final relative distance 0.08709001670072104
# Min relative distance: 0.08709001670072104
# Min iter: 26
# Final dist: 0.008721076346163347
# Before adaptation iterations: 27
# Final iterations: 27
# Time taken: 10.291807174682617
# [0.46073867 0.42145088 0.22598719] [ 0.17148088 -0.01243929  0.1616627 ]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 2
# Starting distance: 0.12602667630867048
# Final relative distance 0.05226763141762626
# Min relative distance: 0.05226763141762626
# Min iter: 28
# Final dist: 0.006587115866090081
# Before adaptation iterations: 29
# Final iterations: 29
# Time taken: 11.350810766220093

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC7')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 103

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(samples=1)[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[2], scaling_factors=[0.001], 
                             i_state=[ref_traj[0]], adaptation_run=True)
ref_traj = dataObject.generateTrajectories(samples=1)[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[2], scaling_factors=[0.001], 
                             i_state=[ref_traj[0]], adaptation_run=True)
# Out:
# [0.46541901 0.3990371  0.26458429] [ 0.05722579  0.27859938 -0.31521989]
# [0.40425244 0.36907085 0.49564054] [-0.01293578  0.29998892 -0.34084788]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC7_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 2
# Starting distance: 0.07769783154534719
# Before adaptation relative distance 0.23889075152011244
# Final relative distance 0.12374592235130735
# Min relative distance: 0.12374592235130735
# Min iter: 29
# Final dist: 0.009614789829275492
# Before adaptation iterations: 20
# Final iterations: 30
# Time taken: 112.8671247959137
# [0.34108332 0.29728538 0.25249123] [ 0.03791475  0.20021071 -0.24715345]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC7_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 2
# Starting distance: 0.10559706925227533
# Final relative distance 0.08714840241094426
# Min relative distance: 0.08714840241094426
# Min iter: 22
# Final dist: 0.00920261588461364
# Before adaptation iterations: 23
# Final iterations: 23
# Time taken: 85.15627074241638

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC4')
evalObject.setIterCount(100)
dataObject = evalObject.setDataObject()

ref_traj = dataObject.generateTrajectories(samples=1)[0]
print(ref_traj[0], ref_traj[time_step])

dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 70
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]

evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[2], scaling_factors=[0.001], 
                             i_state=[ref_traj[0]], adaptation_run=True)

dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 47

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]

evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[2], scaling_factors=[0.001], 
                             i_state=[ref_traj[0]], adaptation_run=True)
# Out:
# [0.86101375 0.74129976 0.91714489] [ 2.02394007 -0.13440488 -1.72261801]
# [0.98403572 0.77807882 0.77531409] [ 1.92979116  0.12385828 -1.81716684]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 2
# Starting distance: 0.2078188190669414
# Final relative distance 0.024306943327415807
# Min relative distance: 0.024306943327415807
# Min iter: 37
# Final dist: 0.0050514402574306245
# Before adaptation iterations: 38
# Final iterations: 38
# Time taken: 16.447600603103638
# [0.83497021 0.51929472 0.94277808] [ 1.19421747  0.39294679 -1.14675032]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 2
# Starting distance: 0.3504783700099139
# Final relative distance 0.012181424333637055
# Min relative distance: 0.012181424333637055
# Min iter: 49
# Final dist: 0.004269325744852216
# Before adaptation iterations: 50
# Final iterations: 50
# Time taken: 21.885645389556885

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')
sys.path.append('../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC8')
evalObject.setIterCount(200)
dataObject = evalObject.setDataObject()

ref_traj = dataObject.generateTrajectories(samples=1)[0]
print(ref_traj[0], ref_traj[time_step])

dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 118
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]

evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[5], scaling_factors=[0.001], 
                             i_state=[ref_traj[0]], adaptation_run=True)

dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 57

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]

evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.01, 
                        correction_steps=[5], scaling_factors=[0.001], 
                             i_state=[ref_traj[0]], adaptation_run=True)
# Out:
# [0.22773095 0.12174979 0.39780443 0.19883583] [-0.23252273 -1.40552355  0.02790679 -1.11596705]
# [0.35042031 0.24121668 0.33872668 0.10024708] [-0.4856154  -0.25933222 -0.27173561 -0.04679856]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC8_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.407892777246939
# Final relative distance 0.022274105469174296
# Min relative distance: 0.022274105469174296
# Min iter: 40
# Final dist: 0.009085446740512737
# Before adaptation iterations: 41
# Final iterations: 41
# Time taken: 8.212348699569702
# [0.20062647 0.3399761  0.15751876 0.2756479 ] [ 0.12759034 -0.52741908  0.09170235 -0.38750535]
# Model file ../../eval-cav/models/model_vp_2_v_OtherBenchC8_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 1.1981131841098256
# Final relative distance 0.007503508310808456
# Min relative distance: 0.007503508310808456
# Min iter: 58
# Final dist: 0.008990052234257258
# Before adaptation iterations: 59
# Final iterations: 59
# Time taken: 11.61286735534668
