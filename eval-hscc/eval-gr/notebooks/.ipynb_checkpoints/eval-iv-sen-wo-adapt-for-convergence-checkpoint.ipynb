# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC1', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[1.33236118, 1.17698394]])[0]
time_step = 77

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [300, 60, 30, 15]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.67184992,1.04788799]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_OtherBenchC1.txt
# [1.33236118 1.17698394] [ 0.42324177 -1.1718629 ]
# [0.67184992 1.04788799] [ 0.27291516 -0.86687264]
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 77
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 0.27291516 -0.86687264] [ 0.42324177 -1.1718629 ]
# 300
# Starting distance: 0.34002521578931083
# Final distance 0.15490466411984183
# Final relative distance 0.4555681664968786
# Min relative distance 0.4555681664968786
# Min iter: 300
# Before adaptation iterations: 300
# Final iterations: 300
# Time taken: 20.101604223251343
# -1.1381554350183019
# 300
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 77
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.34002521578931083
# Final distance 0.15800110677324838
# Final relative distance 0.46467467539569274
# Min relative distance: 0.46467467539569274
# Min iter: 60
# Before adaptation iterations: 60
# Final iterations: 60
# Time taken: 9.812143087387085
# -1.1095033192358805
# 60
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 77
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.34002521578931083
# Final distance 0.16057568685793946
# Final relative distance 0.4722464082117859
# Min relative distance: 0.4722464082117859
# Min iter: 30
# Before adaptation iterations: 30
# Final iterations: 30
# Time taken: 8.41150450706482
# -1.086104455096368
# 30
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 77
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.34002521578931083
# Final distance 0.16578017875427245
# Final relative distance 0.48755260214876095
# Min relative distance: 0.48755260214876095
# Min iter: 15
# Before adaptation iterations: 15
# Final iterations: 15
# Time taken: 7.6632702350616455
# -1.0399284043939938
# 15

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC2', neurons=64, layers=0)

dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.74224485, 1.1416229]])[0]
time_step = 166

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [300, 60, 30, 15]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[1.11786202, 1.18747043]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_OtherBenchC2.txt
# [0.74224485 1.1416229 ] [ 1.11138206 -0.49508727]
# [1.11786202 1.18747043] [ 1.52299075 -0.59491399]
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC2_RBF_0_64_ReLU.h5
# 166
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 1.52299075 -0.59491399] [ 1.11138206 -0.49508727]
# 300
# Starting distance: 0.42354112378355274
# Final distance 0.07752359563598031
# Final relative distance 0.18303676144467643
# Min relative distance 0.18303676144467643
# Min iter: 300
# Before adaptation iterations: 300
# Final iterations: 300
# Time taken: 117.10599088668823
# -2.458205589983945
# 300
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC2_RBF_0_64_ReLU.h5
# 166
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.42354112378355274
# Final distance 0.08250225792030723
# Final relative distance 0.1947916112213683
# Min relative distance: 0.1947916112213683
# Min iter: 60
# Before adaptation iterations: 60
# Final iterations: 60
# Time taken: 26.77800989151001
# -2.3680991670673963
# 60
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC2_RBF_0_64_ReLU.h5
# 166
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.42354112378355274
# Final distance 0.08741912166690496
# Final relative distance 0.20640055181885902
# Min relative distance: 0.20640055181885902
# Min iter: 30
# Before adaptation iterations: 30
# Final iterations: 30
# Time taken: 16.355287313461304
# -2.2842971531409404
# 30
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC2_RBF_0_64_ReLU.h5
# 166
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.42354112378355274
# Final distance 0.09730781604526123
# Final relative distance 0.22974821234829987
# Min relative distance: 0.22974821234829987
# Min iter: 15
# Before adaptation iterations: 15
# Final iterations: 15
# Time taken: 11.248710870742798
# -2.129159530459625
# 15

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC3', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[1.03690469, 0.71034844]])[0]
time_step = 90

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [300, 60, 30, 15]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.62426625, 1.1410296]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_OtherBenchC3.txt
# [1.03690469 0.71034844] [ 0.5018565  -0.06585843]
# [0.62426625 1.1410296 ] [0.3028819  0.09938542]
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 90
# ***** path idx 0 s_factor 0.001 correction steps 1
# [0.3028819  0.09938542] [ 0.5018565  -0.06585843]
# 300
# Starting distance: 0.25864342022763065
# Final distance 0.156212677326036
# Final relative distance 0.6039692685340848
# Min relative distance 0.6039692685340848
# Min iter: 300
# Before adaptation iterations: 300
# Final iterations: 300
# Time taken: 15.602671146392822
# -0.7299505293512702
# 300
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 90
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.25864342022763065
# Final distance 0.15839470240132153
# Final relative distance 0.6124056906683311
# Min relative distance: 0.6124056906683311
# Min iter: 60
# Before adaptation iterations: 60
# Final iterations: 60
# Time taken: 8.239411115646362
# -0.7098692745088663
# 60
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 90
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.25864342022763065
# Final distance 0.1598734217773361
# Final relative distance 0.618122903094277
# Min relative distance: 0.618122903094277
# Min iter: 30
# Before adaptation iterations: 30
# Final iterations: 30
# Time taken: 7.461124420166016
# -0.6964172144890663
# 30
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 90
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.25864342022763065
# Final distance 0.16284188592652732
# Final relative distance 0.62959995573524
# Min relative distance: 0.62959995573524
# Min iter: 15
# Before adaptation iterations: 15
# Final iterations: 15
# Time taken: 7.194871187210083
# -0.6697843706085714
# 15

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='SinglePendulum', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[1.86604794, 0.67884024]])[0]
time_step = 161

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [150, 30, 15, 8]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[1.28034351, 0.78616977]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_SinglePendulum.txt
# [1.86604794 0.67884024] [ 0.63881199 -0.54711763]
# [1.28034351 0.78616977] [ 0.52452693 -0.4303361 ]
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 161
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 0.52452693 -0.4303361 ] [ 0.63881199 -0.54711763]
# 150
# Starting distance: 0.1633982872067768
# Final distance 0.05783018034126541
# Final relative distance 0.3539215822261505
# Min relative distance 0.3539215822261505
# Min iter: 150
# Before adaptation iterations: 150
# Final iterations: 150
# Time taken: 11.896992206573486
# -3.007286354462657
# 150
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 161
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.1633982872067768
# Final distance 0.06139710559764726
# Final relative distance 0.37575121898279523
# Min relative distance: 0.37575121898279523
# Min iter: 30
# Before adaptation iterations: 30
# Final iterations: 30
# Time taken: 4.820534706115723
# -2.833997345563244
# 30
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 161
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.1633982872067768
# Final distance 0.06469921159590589
# Final relative distance 0.3959601578566764
# Min relative distance: 0.3959601578566764
# Min iter: 15
# Before adaptation iterations: 15
# Final iterations: 15
# Time taken: 3.9952569007873535
# -2.682323408535346
# 15
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 161
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.1633982872067768
# Final distance 0.0647719581624714
# Final relative distance 0.39640536794919995
# Min relative distance: 0.39640536794919995
# Min iter: 8
# Before adaptation iterations: 8
# Final iterations: 8
# Time taken: 3.5277488231658936
# -2.5116279569989355
# 8

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen


dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[1.86604794, 0.67884024]])[0]
time_step = 60 #161

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [400, 80, 40, 20]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[1.28034351, 0.78616977]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_SinglePendulum.txt
# [1.86604794 0.67884024] [ 1.49123908 -1.09194609]
# [1.28034351 0.78616977] [ 1.12007647 -0.67086493]
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 1.12007647 -0.67086493] [ 1.49123908 -1.09194609]
# 400
# Starting distance: 0.5613118728133628
# Final distance 0.16159211424599965
# Final relative distance 0.2878829436407259
# Min relative distance 0.2878829436407259
# Min iter: 400
# Before adaptation iterations: 400
# Final iterations: 400
# Time taken: 33.533864974975586
# -1.3519601631099998
# 400
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.5613118728133628
# Final distance 0.1665413922297276
# Final relative distance 0.29670028427334355
# Min relative distance: 0.29670028427334355
# Min iter: 80
# Before adaptation iterations: 80
# Final iterations: 80
# Time taken: 14.243494749069214
# -1.3192050939459699
# 80
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.5613118728133628
# Final distance 0.17157586478111975
# Final relative distance 0.30566940250374686
# Min relative distance: 0.30566940250374686
# Min iter: 40
# Before adaptation iterations: 40
# Final iterations: 40
# Time taken: 11.873809576034546
# -1.2868700799008472
# 40
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.5613118728133628
# Final distance 0.1816160177935815
# Final relative distance 0.3235563446810774
# Min relative distance: 0.3235563446810774
# Min iter: 20
# Before adaptation iterations: 20
# Final iterations: 20
# Time taken: 9.844220876693726
# -1.22512519897729
# 20

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC4', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dataObject.setSteps(200)
dest_traj = dataObject.generateTrajectories(r_states=[[0.38340857, 0.55669372, 0.58930397]])[0]
time_step = 159

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [360, 72, 36, 18]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.32206212, 0.34180113, 0.37530616]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_OtherBenchC4.txt
# [0.38340857 0.55669372 0.58930397] [ 1.03913978 -0.64039672 -0.39003155]
# [0.32206212 0.34180113 0.37530616] [ 0.55845796 -0.46497757 -0.22423766]
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# 159
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 0.55845796 -0.46497757 -0.22423766] [ 1.03913978 -0.64039672 -0.39003155]
# 360
# Starting distance: 0.53787963578753
# Final distance 0.1689813804826194
# Final relative distance 0.31416207128795154
# Min relative distance 0.31416207128795154
# Min iter: 360
# Before adaptation iterations: 360
# Final iterations: 360
# Time taken: 141.55158138275146
# -1.3967951344461247
# 360
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# 159
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.53787963578753
# Final distance 0.17180706537688753
# Final relative distance 0.31941544900717106
# Min relative distance: 0.31941544900717106
# Min iter: 72
# Before adaptation iterations: 72
# Final iterations: 72
# Time taken: 37.23824405670166
# -1.376789117737997
# 72
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# 159
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.53787963578753
# Final distance 0.17428440871044
# Final relative distance 0.32402120681751334
# Min relative distance: 0.32402120681751334
# Min iter: 36
# Before adaptation iterations: 36
# Final iterations: 36
# Time taken: 22.279611110687256
# -1.3595182355163888
# 36
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# 159
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.53787963578753
# Final distance 0.17956169380322784
# Final relative distance 0.3338324819461231
# Min relative distance: 0.3338324819461231
# Min iter: 18
# Before adaptation iterations: 18
# Final iterations: 18
# Time taken: 15.327471733093262
# -1.323531690801074
# 18

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC5', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.2171911, 0.49808728, 0.29292438]])[0]
time_step = 70

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [250, 50, 25, 13]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.39171516, 0.22447754, 0.33403873]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_OtherBenchC5.txt
# [0.2171911  0.49808728 0.29292438] [0.17578161 0.13042461 0.09736385]
# [0.39171516 0.22447754 0.33403873] [ 0.11218481 -0.02772643  0.15109054]
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 0.11218481 -0.02772643  0.15109054] [0.17578161 0.13042461 0.09736385]
# 250
# Starting distance: 0.17872566290585679
# Final distance 0.026751789917637433
# Final relative distance 0.1496807424445188
# Min relative distance 0.1496807424445188
# Min iter: 250
# Before adaptation iterations: 250
# Final iterations: 250
# Time taken: 99.14790105819702
# -3.2993362852829087
# 250
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.17872566290585679
# Final distance 0.030153468122154164
# Final relative distance 0.16871370138958397
# Min relative distance: 0.16871370138958397
# Min iter: 50
# Before adaptation iterations: 50
# Final iterations: 50
# Time taken: 25.13888144493103
# -3.091398586151762
# 50
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.17872566290585679
# Final distance 0.033161033135590795
# Final relative distance 0.18554153106181662
# Min relative distance: 0.18554153106181662
# Min iter: 25
# Before adaptation iterations: 25
# Final iterations: 25
# Time taken: 16.49549436569214
# -2.9262354559546164
# 25
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.17872566290585679
# Final distance 0.03318747261761292
# Final relative distance 0.18568946438931003
# Min relative distance: 0.18568946438931003
# Min iter: 13
# Before adaptation iterations: 13
# Final iterations: 13
# Time taken: 10.775652647018433
# -2.8123566787396954
# 13

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC6', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.24799654, 0.20079748, 0.38178508]])[0]
time_step = 127

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [250, 50, 25, 13]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.4823449, 0.4482593, 0.3137772]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_OtherBenchC6.txt
# [0.24799654 0.20079748 0.38178508] [ 0.25461069 -0.18954533 -0.13130936]
# [0.4823449 0.4482593 0.3137772] [ 0.41479326 -0.34982393 -0.30293713]
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC6_RBF_1_512_ReLU.h5
# 127
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 0.41479326 -0.34982393 -0.30293713] [ 0.25461069 -0.18954533 -0.13130936]
# 250
# Starting distance: 0.2842600499965185
# Final distance 0.031674795991714175
# Final relative distance 0.11142893977575152
# Min relative distance 0.11142893977575152
# Min iter: 250
# Before adaptation iterations: 250
# Final iterations: 250
# Time taken: 23.46246576309204
# -3.8120080067505757
# 250
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC6_RBF_1_512_ReLU.h5
# 127
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.2842600499965185
# Final distance 0.036419838998298655
# Final relative distance 0.12812155277797466
# Min relative distance: 0.12812155277797466
# Min iter: 50
# Before adaptation iterations: 50
# Final iterations: 50
# Time taken: 8.88317084312439
# -3.5695112260578554
# 50
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC6_RBF_1_512_ReLU.h5
# 127
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.2842600499965185
# Final distance 0.04111132487384883
# Final relative distance 0.14462575685310808
# Min relative distance: 0.14462575685310808
# Min iter: 25
# Before adaptation iterations: 25
# Final iterations: 25
# Time taken: 7.065668821334839
# -3.3590174211663175
# 25
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC6_RBF_1_512_ReLU.h5
# 127
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.2842600499965185
# Final distance 0.04105693201431493
# Final relative distance 0.14443440791211348
# Min relative distance: 0.14443440791211348
# Min iter: 13
# Before adaptation iterations: 13
# Final iterations: 13
# Time taken: 6.436240196228027
# -3.2320359021617593
# 13

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC7', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dataObject.setSteps(150)
dest_traj = dataObject.generateTrajectories(r_states=[[0.37993803,0.2731856,0.36936488]])[0]
time_step = 117

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [250, 50, 25, 13]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.29596794,0.42394008,0.49483644]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_OtherBenchC7.txt
# [0.37993803 0.2731856  0.36936488] [ 0.03545953  0.19597451 -0.24987798]
# [0.29596794 0.42394008 0.49483644] [-0.20891249  0.2384528  -0.41090296]
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC7_RBF_1_512_ReLU.h5
# 117
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.2957213813056442
# Final distance 0.010874428942867869
# Final relative distance 0.036772548859524475
# Min relative distance: 0.036772548859524475
# Min iter: 50
# Before adaptation iterations: 50
# Final iterations: 50
# Time taken: 185.2054522037506
# -5.737905065266256
# 50
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC7_RBF_1_512_ReLU.h5
# 117
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.2957213813056442
# Final distance 0.01605958178107689
# Final relative distance 0.05430646140692288
# Min relative distance: 0.05430646140692288
# Min iter: 25
# Before adaptation iterations: 25
# Final iterations: 25
# Time taken: 98.04804396629333
# -5.060593979145413
# 25
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC7_RBF_1_512_ReLU.h5
# 117
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.2957213813056442
# Final distance 0.01621398330180494
# Final relative distance 0.05482857962524835
# Min relative distance: 0.05482857962524835
# Min iter: 13
# Before adaptation iterations: 13
# Final iterations: 13
# Time taken: 54.348204374313354
# -4.849973094958941
# 13
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-8beceee000ea> in <module>
#      27
#      28 for idx in range(4):
# ---> 29     c_step = c_steps[idx]
#      30     evalObject.setIterCount(iters_count[idx])
#      31     evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005,
#
# IndexError: list index out of range

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC8', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[0.32012507, 0.23593369, 0.3696329, 0.17607225]])[0]
time_step = 187

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [500, 100, 50, 25]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.12190108, 0.32483265, 0.13287113, 0.36699083]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_OtherBenchC8.txt
# [0.32012507 0.23593369 0.3696329  0.17607225] [-0.2029552   1.10376923 -0.02257513  0.64867203]
# [0.12190108 0.32483265 0.13287113 0.36699083] [-0.1988582   0.41800017 -0.0589119   0.23490669]
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC8_RBF_1_512_ReLU.h5
# 187
# ***** path idx 0 s_factor 0.001 correction steps 1
# [-0.1988582   0.41800017 -0.0589119   0.23490669] [-0.2029552   1.10376923 -0.02257513  0.64867203]
# 500
# Starting distance: 0.8017593808616281
# Final distance 0.21224942591740636
# Final relative distance 0.2647295821962294
# Min relative distance 0.2647295821962294
# Min iter: 500
# Before adaptation iterations: 500
# Final iterations: 500
# Time taken: 59.35800385475159
# -1.1543950515360037
# 500
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC8_RBF_1_512_ReLU.h5
# 187
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.8017593808616281
# Final distance 0.21828119036982505
# Final relative distance 0.2722527426311426
# Min relative distance: 0.2722527426311426
# Min iter: 100
# Before adaptation iterations: 100
# Final iterations: 100
# Time taken: 20.14496874809265
# -1.1300554730722236
# 100
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC8_RBF_1_512_ReLU.h5
# 187
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.8017593808616281
# Final distance 0.2245635506743772
# Final relative distance 0.2800884604967704
# Min relative distance: 0.2800884604967704
# Min iter: 50
# Before adaptation iterations: 50
# Final iterations: 50
# Time taken: 16.480745315551758
# -1.1054095670427002
# 50
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_OtherBenchC8_RBF_1_512_ReLU.h5
# 187
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.8017593808616281
# Final distance 0.23713548331208267
# Final relative distance 0.29576889148118213
# Min relative distance: 0.29576889148118213
# Min iter: 25
# Before adaptation iterations: 25
# Final iterations: 25
# Time taken: 13.899114847183228
# -1.0580950127305313
# 25

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC9', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dataObject.setSteps(150)
dest_traj = dataObject.generateTrajectories(r_states=[[ 0.53432163, -0.50705631, -0.10642957, 0.90469208]])[0]
time_step = 137

s_factor = 0.001
c_steps = [5, 10, 20]
iters_count = [80, 40, 20]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[ 0.9510333, -0.98411012, -0.29126114, 0.78761868]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(3):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_OtherBenchC9.txt
# [ 0.53432163 -0.50705631 -0.10642957  0.90469208] [-0.37514098 -0.59557826  0.3537923  -0.24489613]
# [ 0.9510333  -0.98411012 -0.29126114  0.78761868] [-0.7722247  -1.10825965  0.45219003  0.34791415]
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC9_RBF_1_512_ReLU.h5
# 137
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.8840949278828819
# Final distance 0.46193115164201026
# Final relative distance 0.5224904442650568
# Min relative distance: 0.5224904442650568
# Min iter: 80
# Before adaptation iterations: 80
# Final iterations: 80
# Time taken: 133.38309454917908
# -0.704804119697321
# 80
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC9_RBF_1_512_ReLU.h5
# 137
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.8840949278828819
# Final distance 0.46796666844324236
# Final relative distance 0.5293172188690974
# Min relative distance: 0.5293172188690974
# Min iter: 40
# Before adaptation iterations: 40
# Final iterations: 40
# Time taken: 71.22032594680786
# -0.6907099450794516
# 40
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC9_RBF_1_512_ReLU.h5
# 137
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.8840949278828819
# Final distance 0.479940944310767
# Final relative distance 0.5428613253783375
# Min relative distance: 0.5428613253783375
# Min iter: 20
# Before adaptation iterations: 20
# Final iterations: 20
# Time taken: 38.59395146369934
# -0.6632777433145742
# 20

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC9Sigmoid', act_fn='Sigmoid', neurons=64, layers=0)

dataObject = evalObject.setDataObject()
dataObject.setSteps(200)
dest_traj = dataObject.generateTrajectories(r_states=[[-0.93061055, -0.50516322, 0.46661147, -0.49595134]])[0]
time_step = 165

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [700, 140, 70, 35]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[-0.9729112, -0.1072407, 0.28281309, -0.08520518]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_OtherBenchC9Sigmoid.txt
# [-0.93061055 -0.50516322  0.46661147 -0.49595134] [-0.39951305  0.99052087  0.27540891  0.26624766]
# [-0.9729112  -0.1072407   0.28281309 -0.08520518] [0.00676568 1.02437507 0.75491159 0.65960279]
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC9Sigmoid_RBF_0_64_Sigmoid.h5
# 165
# ***** path idx 0 s_factor 0.001 correction steps 1
# [0.00676568 1.02437507 0.75491159 0.65960279] [-0.39951305  0.99052087  0.27540891  0.26624766]
# 700
# Starting distance: 0.7421991562553737
# Final distance 0.04259327217683205
# Final relative distance 0.057387928587427126
# Min relative distance 0.057387928587427126
# Min iter: 700
# Before adaptation iterations: 700
# Final iterations: 700
# Time taken: 71.18283748626709
# -1.7731135011340342
# 700
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC9Sigmoid_RBF_0_64_Sigmoid.h5
# 165
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.7421991562553737
# Final distance 0.04753438890944875
# Final relative distance 0.064045328681421
# Min relative distance: 0.064045328681421
# Min iter: 140
# Before adaptation iterations: 140
# Final iterations: 140
# Time taken: 26.284122228622437
# -1.7050179160030439
# 140
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC9Sigmoid_RBF_0_64_Sigmoid.h5
# 165
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.7421991562553737
# Final distance 0.05244453862978735
# Final relative distance 0.07066100545625302
# Min relative distance: 0.07066100545625302
# Min iter: 70
# Before adaptation iterations: 70
# Final iterations: 70
# Time taken: 22.074612617492676
# -1.6440288387902053
# 70
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC9Sigmoid_RBF_0_64_Sigmoid.h5
# 165
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.7421991562553737
# Final distance 0.062273399181104104
# Final relative distance 0.08390389379488496
# Min relative distance: 0.08390389379488496
# Min iter: 35
# Before adaptation iterations: 35
# Final iterations: 35
# Time taken: 19.296254634857178
# -1.5374541200762726
# 35

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC9Tanh', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[-0.64343721, -0.35481454, 0.31645362, -0.48215772]])[0]
time_step = 281

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [700, 140, 70, 35]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[-0.94942456, -0.59297976, 0.20508661, -0.20818601]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_OtherBenchC9Tanh.txt
# [-0.64343721 -0.35481454  0.31645362 -0.48215772] [ 0.43744406  0.47015409 -1.00795839 -0.40777501]
# [-0.94942456 -0.59297976  0.20508661 -0.20818601] [ 0.6853023   0.82897056 -0.47958519 -0.21695601]
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC9Tanh_RBF_1_512_ReLU.h5
# 281
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 0.6853023   0.82897056 -0.47958519 -0.21695601] [ 0.43744406  0.47015409 -1.00795839 -0.40777501]
# 700
# Starting distance: 0.711177254814503
# Final distance 0.09039741933816266
# Final relative distance 0.12710954790271112
# Min relative distance 0.12710954790271112
# Min iter: 700
# Before adaptation iterations: 700
# Final iterations: 700
# Time taken: 70.2250726222992
# -1.27974546564983
# 700
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC9Tanh_RBF_1_512_ReLU.h5
# 281
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.711177254814503
# Final distance 0.09261653120450548
# Final relative distance 0.13022988372802044
# Min relative distance: 0.13022988372802044
# Min iter: 140
# Before adaptation iterations: 140
# Final iterations: 140
# Time taken: 26.24765110015869
# -1.2646990674124474
# 140
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC9Tanh_RBF_1_512_ReLU.h5
# 281
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.711177254814503
# Final distance 0.09414970787090321
# Final relative distance 0.1323857128915918
# Min relative distance: 0.1323857128915918
# Min iter: 70
# Before adaptation iterations: 70
# Final iterations: 70
# Time taken: 22.770955085754395
# -1.2545126879522794
# 70
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC9Tanh_RBF_1_512_ReLU.h5
# 281
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.711177254814503
# Final distance 0.09721666801327462
# Final relative distance 0.13669822446533633
# Min relative distance: 0.13669822446533633
# Min iter: 35
# Before adaptation iterations: 35
# Final iterations: 35
# Time taken: 19.28488254547119
# -1.2346244661771695
# 35

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC9Tanh', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[-0.64343721, -0.35481454, 0.31645362, -0.48215772]])[0]
time_step = 79 #281

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [700, 140, 70, 35]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[-0.94942456, -0.59297976, 0.20508661, -0.20818601]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_OtherBenchC9Tanh.txt
# [-0.64343721 -0.35481454  0.31645362 -0.48215772] [-0.73055448 -0.04558704  0.10740664 -0.48958008]
# [-0.94942456 -0.59297976  0.20508661 -0.20818601] [-1.1086124  -0.13665417  0.11081449 -0.23004253]
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC9Tanh_RBF_0_64_ReLU.h5
# 43
# ***** path idx 0 s_factor 0.001 correction steps 1
# [-1.1086124  -0.13665417  0.11081449 -0.23004253] [-0.73055448 -0.04558704  0.10740664 -0.48958008]
# 700
# Starting distance: 0.4675386285455448
# Final distance 0.004487239296442483
# Final relative distance 0.009597579798703976
# Min relative distance 0.009597579798703976
# Min iter: 472
# Before adaptation iterations: 472
# Final iterations: 472
# Time taken: 43.40363383293152
# -4.275081076845267
# 472
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC9Tanh_RBF_0_64_ReLU.h5
# 43
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.4675386285455448
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ed8d4dc543fc> in <module>
#      30     evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005,
#      31                         correction_steps=[c_step],  scaling_factors=[s_factor],
# ---> 32                              i_state=[ref_traj[0]], adaptation_run=False)
#      33     final_rel_dist = evalObject.getFRelDistance()
#      34     f_iter = evalObject.getFIterations()
#
# ~/Research/cps-falsification/NeuralExplorerGradient/core/evaluation_isen.py in reachDestInvPaths(self, dests, d_time_steps, threshold, correction_steps, scaling_factors, i_state, adaptation_run)
#     421                                                      scaling_factor=s_factor, iter_bound=self.iter_count,
#     422                                                      adaptation_run=adaptation_run, adaptation_factor=adaptation_factor,
# --> 423                                                      dynamics=self.dynamics)
#     424                         print("Time taken: " + str(time.time() - start_time))
#     425
#
# ~/Research/cps-falsification/NeuralExplorerGradient/core/evaluation_isen.py in reachDestInvNonBaseline(self, ref_traj, paths, d_time_step, threshold, model_v, correction_steps, iter_bound, scaling_factor, adaptation_factor, adaptation_run, rand_area, dynamics)
#     646                 while step < correction_steps:
#     647                     data_point = self.data_object.createDataPoint(x_val, xp_val, v_val, vp_val_normalized, t_val)
# --> 648                     predicted_v = self.evalModel(input=data_point, eval_var='v', model=model_v)
#     649                     predicted_v_scaled = [val * scaling_factor for val in predicted_v]
#     650                     new_init_state = [self.check_for_bounds(x_val + predicted_v_scaled)]
#
# ~/Research/cps-falsification/NeuralExplorerGradient/core/evaluation.py in evalModel(self, input, eval_var, model)
#     113             xp_vp_t_pair = xp_vp_t_pair + [input[4]]
#     114             xp_vp_t_pair = np.asarray([xp_vp_t_pair], dtype=np.float64)
# --> 115             predicted_v = model.predict(xp_vp_t_pair)
#     116             predicted_v = predicted_v.flatten()
#     117             output = predicted_v
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1577           use_multiprocessing=use_multiprocessing,
#    1578           model=self,
# -> 1579           steps_per_execution=self._steps_per_execution)
#    1580
#    1581       # Container that configures and calls `tf.keras.Callback`s.
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1115         use_multiprocessing=use_multiprocessing,
#    1116         distribution_strategy=ds_context.get_strategy(),
# -> 1117         model=model)
#    1118
#    1119     strategy = ds_context.get_strategy()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     309     # 5. disabled static optimizations
#     310
# --> 311     indices_dataset = dataset_ops.DatasetV2.range(1)
#     312     if shuffle != "batch":
#     313       indices_dataset = indices_dataset.repeat(epochs)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in range(*args, **kwargs)
#     953       ValueError: if len(args) == 0.
#     954     """
# --> 955     return RangeDataset(*args, **kwargs)
#     956
#     957   @staticmethod
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, *args, **kwargs)
#    3576         stop=self._stop,
#    3577         step=self._step,
# -> 3578         **self._flat_structure)
#    3579     super(RangeDataset, self).__init__(variant_tensor)
#    3580
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/gen_dataset_ops.py in range_dataset(start, stop, step, output_types, output_shapes, name)
#    5318         _ctx._context_handle, tld.device_name, "RangeDataset", name,
#    5319         tld.op_callbacks, start, stop, step, "output_types", output_types,
# -> 5320         "output_shapes", output_shapes)
#    5321       return _result
#    5322     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC10', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[ 9.66069542, -4.45059512, 2.34987937, 1.68742395]])[0]
time_step = 129

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [400, 80, 40, 20]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[ 9.66747036, -4.36939933, 2.01494191, 1.3610423]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_OtherBenchC10.txt
# [ 9.66069542 -4.45059512  2.34987937  1.68742395] [ 7.22799165 -2.81921383  2.6329884   2.65454006]
# [ 9.66747036 -4.36939933  2.01494191  1.3610423 ] [ 7.75416575 -2.79669015  2.57065523  2.50968187]
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC10_RBF_1_512_ReLU.h5
# 129
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 7.75416575 -2.79669015  2.57065523  2.50968187] [ 7.22799165 -2.81921383  2.6329884   2.65454006]
# 400
# Starting distance: 0.5497597858234292
# Final distance 0.07620837327368382
# Final relative distance 0.1386212219206595
# Min relative distance 0.1386212219206595
# Min iter: 400
# Before adaptation iterations: 400
# Final iterations: 400
# Time taken: 117.0078661441803
# -2.1454256931145204
# 400
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC10_RBF_1_512_ReLU.h5
# 129
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.5497597858234292
# Final distance 0.08149339449494765
# Final relative distance 0.14823455006423758
# Min relative distance: 0.14823455006423758
# Min iter: 80
# Before adaptation iterations: 80
# Final iterations: 80
# Time taken: 30.59318232536316
# -2.0726264012584084
# 80
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC10_RBF_1_512_ReLU.h5
# 129
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.5497597858234292
# Final distance 0.08665259774023097
# Final relative distance 0.15761901829622343
# Min relative distance: 0.15761901829622343
# Min iter: 40
# Before adaptation iterations: 40
# Final iterations: 40
# Time taken: 19.75671100616455
# -2.005978454381589
# 40
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_OtherBenchC10_RBF_1_512_ReLU.h5
# 129
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.5497597858234292
# Final distance 0.09702434121432806
# Final relative distance 0.17648497346710285
# Min relative distance: 0.17648497346710285
# Min iter: 20
# Before adaptation iterations: 20
# Final iterations: 20
# Time taken: 14.368941068649292
# -1.8832306650407067
# 20

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='DoublePendulumLess', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[1.41599123, 1.44045803, 1.19088411, 1.24922277]])[0]
time_step = 111

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [400, 80, 40, 20]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[1.36245851, 1.05889146, 1.36966607, 1.33938652]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_DoublePendulumLess.txt
# [1.41599123 1.44045803 1.19088411 1.24922277] [ 1.64392981  0.15295703 -0.78591581 -1.22480753]
# [1.36245851 1.05889146 1.36966607 1.33938652] [ 1.72274914 -0.12297906 -0.60518795 -1.35040318]
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_DoublePendulumLess_RBF_1_512_ReLU.h5
# 111
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 1.72274914 -0.12297906 -0.60518795 -1.35040318] [ 1.64392981  0.15295703 -0.78591581 -1.22480753]
# 400
# Starting distance: 0.36164905882914544
# Final distance 0.11922001674324904
# Final relative distance 0.3296566487114028
# Min relative distance 0.3296566487114028
# Min iter: 400
# Before adaptation iterations: 400
# Final iterations: 400
# Time taken: 75.93804574012756
# -1.2048454018061912
# 400
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_DoublePendulumLess_RBF_1_512_ReLU.h5
# 111
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.36164905882914544
# Final distance 0.12219762150270091
# Final relative distance 0.3378900581086013
# Min relative distance: 0.3378900581086013
# Min iter: 80
# Before adaptation iterations: 80
# Final iterations: 80
# Time taken: 20.873536586761475
# -1.1780614661982614
# 80
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_DoublePendulumLess_RBF_1_512_ReLU.h5
# 111
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.36164905882914544
# Final distance 0.12488072552215745
# Final relative distance 0.34530914009969843
# Min relative distance: 0.34530914009969843
# Min iter: 40
# Before adaptation iterations: 40
# Final iterations: 40
# Time taken: 15.783424615859985
# -1.1544798150420341
# 40
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_DoublePendulumLess_RBF_1_512_ReLU.h5
# 111
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.36164905882914544
# Final distance 0.13026449253144673
# Final relative distance 0.36019585659419023
# Min relative distance: 0.36019585659419023
# Min iter: 20
# Before adaptation iterations: 20
# Final iterations: 20
# Time taken: 13.869453191757202
# -1.108653218162599
# 20

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='DoublePendulumMore', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[1.03121511, 1.13753321, 1.04485504, 1.14575856]])[0]
time_step = 47

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [300, 60, 30, 15]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[1.16665916, 1.36808005, 1.03275535, 1.15056093]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_DoublePendulumMore.txt
# [1.03121511 1.13753321 1.04485504 1.14575856] [ 0.80980915  0.71902499 -1.43665408 -1.29119013]
# [1.16665916 1.36808005 1.03275535 1.15056093] [ 0.9031353   0.85023583 -1.58534008 -1.50003601]
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_DoublePendulumMore_RBF_1_512_ReLU.h5
# 47
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 0.9031353   0.85023583 -1.58534008 -1.50003601] [ 0.80980915  0.71902499 -1.43665408 -1.29119013]
# 300
# Starting distance: 0.3027378172675233
# Final distance 0.0744329135921114
# Final relative distance 0.2458659253869712
# Min relative distance 0.2458659253869712
# Min iter: 300
# Before adaptation iterations: 300
# Final iterations: 300
# Time taken: 49.01516795158386
# -2.0310055201975246
# 300
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_DoublePendulumMore_RBF_1_512_ReLU.h5
# 47
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.3027378172675233
# Final distance 0.07853143088020688
# Final relative distance 0.25940409952421056
# Min relative distance: 0.25940409952421056
# Min iter: 60
# Before adaptation iterations: 60
# Final iterations: 60
# Time taken: 14.497727632522583
# -1.9534105492402762
# 60
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_DoublePendulumMore_RBF_1_512_ReLU.h5
# 47
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.3027378172675233
# Final distance 0.08235460619290373
# Final relative distance 0.2720327672843351
# Min relative distance: 0.2720327672843351
# Min iter: 30
# Before adaptation iterations: 30
# Final iterations: 30
# Time taken: 10.919983148574829
# -1.8845959351596095
# 30
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_DoublePendulumMore_RBF_1_512_ReLU.h5
# 47
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.3027378172675233
# Final distance 0.089959662055675
# Final relative distance 0.2971536984300163
# Min relative distance: 0.2971536984300163
# Min iter: 15
# Before adaptation iterations: 15
# Final iterations: 15
# Time taken: 8.808813571929932
# -1.7567295335416782
# 15

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='InvPendulumC', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[ 0.21983048, 0.09054881, 0.1598372, -0.18513457]])[0]
time_step = 181 #187

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [150, 30, 15, 8]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[ 0.01668265, 0.08621481, 0.0257477, -0.02263589]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(1/final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_InvPendulumC.txt
# [ 0.21983048  0.09054881  0.1598372  -0.18513457] [ 0.20443062 -0.10424363  0.00736594 -0.00737599]
# [ 0.01668265  0.08621481  0.0257477  -0.02263589] [ 0.03771491 -0.01925816  0.00169987 -0.00249266]
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_InvPendulumC_RBF_1_512_ReLU.h5
# 181
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 0.03771491 -0.01925816  0.00169987 -0.00249266] [ 0.20443062 -0.10424363  0.00736594 -0.00737599]
# 150
# Starting distance: 0.18727683412869664
# Final distance 0.03312455018025775
# Final relative distance 0.17687478718000196
# Min relative distance 0.17687478718000196
# Min iter: 150
# Before adaptation iterations: 150
# Final iterations: 150
# Time taken: 5.973572731018066
# 5.015560464565908
# 150
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_InvPendulumC_RBF_1_512_ReLU.h5
# 181
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.18727683412869664
# Final distance 0.034396586188202474
# Final relative distance 0.183667063511791
# Min relative distance: 0.183667063511791
# Min iter: 30
# Before adaptation iterations: 30
# Final iterations: 30
# Time taken: 3.4955523014068604
# 4.906458116646292
# 30
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_InvPendulumC_RBF_1_512_ReLU.h5
# 181
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.18727683412869664
# Final distance 0.03476866234135328
# Final relative distance 0.1856538343523057
# Min relative distance: 0.1856538343523057
# Min iter: 15
# Before adaptation iterations: 15
# Final iterations: 15
# Time taken: 3.1852917671203613
# 4.875307178394114
# 15
# ../../../eval-hscc/eval-gr/models/convergence-less-data/model_vp_2_v_InvPendulumC_RBF_1_512_ReLU.h5
# 181
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.18727683412869664
# Final distance 0.03474684870158207
# Final relative distance 0.18553735630592746
# Min relative distance: 0.18553735630592746
# Min iter: 8
# Before adaptation iterations: 8
# Final iterations: 8
# Time taken: 3.0952062606811523
# 4.572303974322827
# 8

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='ACCNonLinear3L', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dataObject.setSteps(100)
dest_traj = dataObject.generateTrajectories(r_states=[[90.12313856, 32.1101962, 0., 10.53908006, 30.19112816, 0.]])[0]
time_step = 78

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [1500, 300, 150, 75]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[91.75808158, 32.09576592, 0., 10.35377563, 30.11422018, 0.]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_ACCNonLinear3L.txt
# [90.12313856 32.1101962   0.         10.53908006 30.19112816  0.        ] [114.94004183  31.32043553  -1.61944201  34.06721823  30.120878
#   -0.13305949]
# [91.75808158 32.09576592  0.         10.35377563 30.11422018  0.        ] [ 1.16563734e+02  3.13060230e+01 -1.61940590e+00  3.38263135e+01
#   3.00589018e+01 -1.03599640e-01]
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_ACCNonLinear3L_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 1.16563734e+02  3.13060230e+01 -1.61940590e+00  3.38263135e+01
#   3.00589018e+01 -1.03599640e-01] [114.94004183  31.32043553  -1.61944201  34.06721823  30.120878
#   -0.13305949]
# 1500
# Starting distance: 1.642963562774088
# Final distance 0.2066523603054416
# Final relative distance 0.1257802455195757
# Min relative distance 0.1257802455195757
# Min iter: 1500
# Before adaptation iterations: 1500
# Final iterations: 1500
# Time taken: 152.57904028892517
# -0.6002583745838493
# 1500
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_ACCNonLinear3L_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 1.642963562774088
# Final distance 0.2111221981408883
# Final relative distance 0.1285008401430496
# Min relative distance: 0.1285008401430496
# Min iter: 300
# Before adaptation iterations: 300
# Final iterations: 300
# Time taken: 56.5637903213501
# -0.5940626885937875
# 300
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_ACCNonLinear3L_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 1.642963562774088
# Final distance 0.21561533565274277
# Final relative distance 0.13123561625961055
# Min relative distance: 0.13123561625961055
# Min iter: 150
# Before adaptation iterations: 150
# Final iterations: 150
# Time taken: 46.84692692756653
# -0.5879655233582833
# 150
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_ACCNonLinear3L_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 1.642963562774088
# Final distance 0.2246525196171282
# Final relative distance 0.13673615453638552
# Min relative distance: 0.13673615453638552
# Min iter: 75
# Before adaptation iterations: 75
# Final iterations: 75
# Time taken: 40.56612706184387
# -0.5760777586879612
# 75

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='ACCNonLinear5L', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dataObject.setSteps(120)
dest_traj = dataObject.generateTrajectories(r_states=[[90.08631338, 32.03149398, 0., 10.08003133, 30.06912549, 0.]])[0]
time_step = 119

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [1500, 300, 150, 75]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[91.44319303, 32.18008823, 0., 10.58631604, 30.05234208, 0.]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_ACCNonLinear5L.txt
# [90.08631338 32.03149398  0.         10.08003133 30.06912549  0.        ] [127.50678354  30.52210405  -1.85891732  45.69174847  29.70322053
#   -0.44248785]
# [91.44319303 32.18008823  0.         10.58631604 30.05234208  0.        ] [129.04032943  30.67035164  -1.85933772  46.19110546  29.71428965
#   -0.40913143]
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_ACCNonLinear5L_RBF_1_512_ReLU.h5
# 119
# ***** path idx 0 s_factor 0.001 correction steps 1
# [129.04032943  30.67035164  -1.85933772  46.19110546  29.71428965
#   -0.40913143] [127.50678354  30.52210405  -1.85891732  45.69174847  29.70322053
#   -0.44248785]
# 1500
# Starting distance: 1.6199793528667032
# Final distance 0.9764456073337748
# Final relative distance 0.6027518842174525
# Min relative distance 0.6027518842174525
# Min iter: 1500
# Before adaptation iterations: 1500
# Final iterations: 1500
# Time taken: 231.4160237312317
# -0.146574282221989
# 1500
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_ACCNonLinear5L_RBF_1_512_ReLU.h5
# 119
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 1.6199793528667032
# Final distance 0.978154102948244
# Final relative distance 0.6038065245815077
# Min relative distance: 0.6038065245815077
# Min iter: 300
# Before adaptation iterations: 300
# Final iterations: 300
# Time taken: 68.49084568023682
# -0.14606813227371734
# 300
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_ACCNonLinear5L_RBF_1_512_ReLU.h5
# 119
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 1.6199793528667032
# Final distance 0.9790800091612231
# Final relative distance 0.6043780789110987
# Min relative distance: 0.6043780789110987
# Min iter: 150
# Before adaptation iterations: 150
# Final iterations: 150
# Time taken: 52.76883602142334
# -0.14579419741393
# 150
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_ACCNonLinear5L_RBF_1_512_ReLU.h5
# 119
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 1.6199793528667032
# Final distance 0.9809426172373356
# Final relative distance 0.6055278516367921
# Min relative distance: 0.6055278516367921
# Min iter: 75
# Before adaptation iterations: 75
# Final iterations: 75
# Time taken: 42.611143589019775
# -0.14524391760796387
# 75

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='ACCNonLinear7L', neurons=64, layers=0)

dataObject = evalObject.setDataObject()
dataObject.setSteps(120)
dest_traj = dataObject.generateTrajectories(r_states=[[90.48556089, 32.03664094, 0., 10.77659942, 30.18391374, 0.]])[0]
time_step = 93

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [1500, 300, 150, 75]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[91.70175944, 32.19664741, 0., 10.99454726, 30.0778881, 0.]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_ACCNonLinear7L.txt
# [90.48556089 32.03664094  0.         10.77659942 30.18391374  0.        ] [119.91349736  30.99532027  -1.73048676  38.90312402  30.34434561
#    0.2769708 ]
# [91.70175944 32.19664741  0.         10.99454726 30.0778881   0.        ] [121.27841064  31.15506795  -1.73091272  39.01770169  30.22487396
#    0.25511032]
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_ACCNonLinear7L_RBF_0_64_ReLU.h5
# 93
# ***** path idx 0 s_factor 0.001 correction steps 1
# [121.27841064  31.15506795  -1.73091272  39.01770169  30.22487396
#    0.25511032] [119.91349736  30.99532027  -1.73048676  38.90312402  30.34434561
#    0.2769708 ]
# 1500
# Starting distance: 1.3843363551859658
# Final distance 0.004413498302958767
# Final relative distance 0.003188169035960828
# Min relative distance 0.003188169035960828
# Min iter: 1474
# Before adaptation iterations: 1474
# Final iterations: 1474
# Time taken: 346.04303193092346
# -1.6936625919102972
# 1474
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_ACCNonLinear7L_RBF_0_64_ReLU.h5
# 93
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 1.3843363551859658
# Final distance 0.00404049459915019
# Final relative distance 0.002918723173030739
# Min relative distance: 0.002918723173030739
# Min iter: 296
# Before adaptation iterations: 296
# Final iterations: 296
# Time taken: 92.65905952453613
# -1.7127074958233461
# 296
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_ACCNonLinear7L_RBF_0_64_ReLU.h5
# 93
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 1.3843363551859658
# Final distance 0.0023696753577594283
# Final relative distance 0.001711777162307564
# Min relative distance: 0.001711777162307564
# Min iter: 149
# Before adaptation iterations: 149
# Final iterations: 149
# Time taken: 66.63089871406555
# -1.8567468268891816
# 149
# ../../../eval-hscc/eval-gr/models/convergence-more-data/model_vp_2_v_ACCNonLinear7L_RBF_0_64_ReLU.h5
# 93
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 1.3843363551859658
# Final distance 0.004248066930697192
# Final relative distance 0.0030686667404082766
# Min relative distance: 0.0030686667404082766
# Min iter: 75
# Before adaptation iterations: 75
# Final iterations: 75
# Time taken: 52.38942790031433
# -1.675366849150261
# 75

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='ACCNonLinear10L', neurons=512, layers=1)

dataObject = evalObject.setDataObject()
dataObject.setSteps(120)
dest_traj = dataObject.generateTrajectories(r_states=[[90.21590329, 32.17241419, 0., 10.18170239, 30.00183321, 0.]])[0]
time_step = 101

s_factor = 0.001
c_steps = [1, 5, 10, 20]
iters_count = [1000, 200, 100, 50]
print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[91.22323268, 32.10670788, 0., 10.28688787, 30.02237113, 0.]])[0]
print(ref_traj[0], ref_traj[time_step])

for idx in range(4):
    c_step = c_steps[idx]
    evalObject.setIterCount(iters_count[idx])
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[c_step],  scaling_factors=[s_factor], 
                             i_state=[ref_traj[0]], adaptation_run=False)
    final_rel_dist = evalObject.getFRelDistance()
    f_iter = evalObject.getFIterations()
    print(np.log10(final_rel_dist)/(s_factor * c_step * f_iter))
    print(f_iter)
# Out:
# ../../../eval-hscc/eval-gr/dconfigs_inv/d_object_ACCNonLinear10L.txt
# [90.21590329 32.17241419  0.         10.18170239 30.00183321  0.        ] [ 1.22254911e+02  3.09904786e+01 -1.77777552e+00  4.04904889e+01
#   3.00209885e+01  3.19469146e-02]
# [91.22323268 32.10670788  0.         10.28688787 30.02237113  0.        ] [ 1.23195923e+02  3.09248928e+01 -1.77759623e+00  4.06210482e+01
#   3.00537401e+01  5.28018314e-02]
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_ACCNonLinear10L_RBF_1_512_ReLU.h5
# 101
# ***** path idx 0 s_factor 0.001 correction steps 1
# [ 1.23195923e+02  3.09248928e+01 -1.77759623e+00  4.06210482e+01
#   3.00537401e+01  5.28018314e-02] [ 1.22254911e+02  3.09904786e+01 -1.77777552e+00  4.04904889e+01
#   3.00209885e+01  3.19469146e-02]
# 1000
# Starting distance: 0.9530789869701273
# Final distance 0.6174772352070349
# Final relative distance 0.647876244937492
# Min relative distance 0.647876244937492
# Min iter: 1000
# Before adaptation iterations: 1000
# Final iterations: 1000
# Time taken: 290.6377158164978
# -0.18850794362574658
# 1000
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_ACCNonLinear10L_RBF_1_512_ReLU.h5
# 101
# ***** path idx 0 s_factor 0.001 correction steps 5
# Starting distance: 0.9530789869701273
# Final distance 0.6185032930326609
# Final relative distance 0.6489528165959312
# Min relative distance: 0.6489528165959312
# Min iter: 200
# Before adaptation iterations: 200
# Final iterations: 200
# Time taken: 74.17347025871277
# -0.1877868782950757
# 200
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_ACCNonLinear10L_RBF_1_512_ReLU.h5
# 101
# ***** path idx 0 s_factor 0.001 correction steps 10
# Starting distance: 0.9530789869701273
# Final distance 0.6188028170519477
# Final relative distance 0.6492670864763731
# Min relative distance: 0.6492670864763731
# Min iter: 100
# Before adaptation iterations: 100
# Final iterations: 100
# Time taken: 47.75129961967468
# -0.18757661241138773
# 100
# ../../../eval-hscc/eval-gr/models/model_vp_2_v_ACCNonLinear10L_RBF_1_512_ReLU.h5
# 101
# ***** path idx 0 s_factor 0.001 correction steps 20
# Starting distance: 0.9530789869701273
# Final distance 0.6194315786890906
# Final relative distance 0.6499268026654182
# Min relative distance: 0.6499268026654182
# Min iter: 50
# Before adaptation iterations: 50
# Final iterations: 50
# Time taken: 33.70430111885071
# -0.18713555257028983
# 50
