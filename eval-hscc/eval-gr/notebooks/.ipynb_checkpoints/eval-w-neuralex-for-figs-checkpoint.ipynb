# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC2')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dataObject.setSteps(170)
dest_traj = dataObject.generateTrajectories(r_states=[[1.06081934, 0.65125586]])[0]
time_step = 76

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.71615204, 0.87601394]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.005], 
                             i_state=[ref_traj[0]], adaptation_run=False)
# Out:
# ../../../eval-fm/eval-gr/dconfigs_inv/d_object_OtherBenchC2.txt
# [1.06081934 0.65125586] [ 1.35442615 -0.01804682]
# [0.71615204 0.87601394] [1.14323862 0.32844171]
# ../../../eval-fm/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.005 correction steps 1
# [1.14323862 0.32844171] [ 1.35442615 -0.01804682]
# 500
# Starting distance: 0.4057763841421795
# Final relative distance 0.0019133300322956473
# Min relative distance 0.0019133300322956473
# Min iter: 81
# Before adaptation iterations: 81
# Final iterations: 81
# Time taken: 3.6853771209716797

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC3')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[1.03690469, 0.71034844]])[0]
time_step = 55

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[0.62426625, 1.1410296]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.01], i_state=[ref_traj[0]],
                             adaptation_run=False)
# Out:
# ../../../eval-fm/eval-gr/dconfigs_inv/d_object_OtherBenchC3.txt
# [1.03690469 0.71034844] [0.56601351 0.00166749]
# [0.62426625 1.1410296 ] [0.33858231 0.21339185]
# ../../../eval-fm/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.01 correction steps 1
# [0.33858231 0.21339185] [0.56601351 0.00166749]
# 500
# Starting distance: 0.3107284256691441
# Final relative distance 0.002344251793428462
# Min relative distance 0.002344251793428462
# Min iter: 31
# Before adaptation iterations: 31
# Final iterations: 31
# Time taken: 1.3753361701965332

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC9Tanh')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[-0.90804677, -0.2088056,   0.54512056, -0.38022436]])[0]
time_step = 177

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[-0.52187253, -0.54350975,  0.54205043, -0.20722052]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1], scaling_factors=[0.01], i_state=[ref_traj[0]],
                             adaptation_run=False)
# Out:
# ../../../eval-fm/eval-gr/dconfigs_inv/d_object_OtherBenchC9Tanh.txt
# [-0.90804677 -0.2088056   0.54512056 -0.38022436] [ 0.00811955  0.93687141 -0.16599105 -0.39795619]
# [-0.52187253 -0.54350975  0.54205043 -0.20722052] [-0.38391654  0.64379653  0.1144356  -0.26362509]
# ../../../eval-fm/eval-gr/models/model_vp_2_v_OtherBenchC9Tanh_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.01 correction steps 1
# [-0.38391654  0.64379653  0.1144356  -0.26362509] [ 0.00811955  0.93687141 -0.16599105 -0.39795619]
# 500
# Starting distance: 0.5798871725644366
# Final relative distance 0.0001945679106244393
# Min relative distance 0.0001945679106244393
# Min iter: 58
# Before adaptation iterations: 58
# Final iterations: 58
# Time taken: 2.370702028274536

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC9Tanh')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dataObject.setSteps(250)

# dest_traj = dataObject.generateTrajectories(r_states=[[-0.91036981, -0.41154395,  0.34706167, -0.2648444 ]])[0]
dest_traj = dataObject.generateTrajectories(r_states=[[-0.90804677, -0.2088056,   0.54512056, -0.38022436]])[0]
time_step = 177

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
# ref_traj = dataObject.generateTrajectories(r_states=[[-0.57901881, -0.17855466,  0.65901188, -0.28764357]])[0]
ref_traj = dataObject.generateTrajectories(r_states=[[-0.52187253, -0.54350975,  0.54205043, -0.20722052]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[1, 5], scaling_factors=[0.02], i_state=[ref_traj[0]],
                             adaptation_run=False)
# Out:
# ../../../eval-fm/eval-gr/dconfigs_inv/d_object_OtherBenchC9Tanh.txt
# [-0.90804677 -0.2088056   0.54512056 -0.38022436] [ 0.00811955  0.93687141 -0.16599105 -0.39795619]
# [-0.52187253 -0.54350975  0.54205043 -0.20722052] [-0.38391654  0.64379653  0.1144356  -0.26362509]
# ../../../eval-fm/eval-gr/models/model_vp_2_v_OtherBenchC9Tanh_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.02 correction steps 1
# [-0.38391654  0.64379653  0.1144356  -0.26362509] [ 0.00811955  0.93687141 -0.16599105 -0.39795619]
# 500
# Starting distance: 0.5798871725644366
# Final relative distance 0.007677604809275625
# Min relative distance 0.007677604809275625
# Min iter: 41
# Before adaptation iterations: 41
# Final iterations: 41
# Time taken: 4.935033798217773
# ***** path idx 0 s_factor 0.02 correction steps 5
# Starting distance: 0.5798871725644366
# Final relative distance 0.004321360456710549
# Min relative distance: 0.004321360456710549
# Min iter: 9
# Before adaptation iterations: 9
# Final iterations: 9
# Time taken: 2.1329174041748047

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC9Tanh')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dataObject.setSteps(250)

# dest_traj = dataObject.generateTrajectories(r_states=[[-0.91036981, -0.41154395,  0.34706167, -0.2648444 ]])[0]
dest_traj = dataObject.generateTrajectories(r_states=[[-0.90804677, -0.2088056,   0.54512056, -0.38022436]])[0]
time_step = 177

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
# ref_traj = dataObject.generateTrajectories(r_states=[[-0.57901881, -0.17855466,  0.65901188, -0.28764357]])[0]
ref_traj = dataObject.generateTrajectories(r_states=[[-0.52187253, -0.54350975,  0.54205043, -0.20722052]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[40], scaling_factors=[0.01], i_state=[ref_traj[0]],
                             adaptation_run=False)
# Out:
# ../../../eval-fm/eval-gr/dconfigs_inv/d_object_OtherBenchC9Tanh.txt
# [-0.90804677 -0.2088056   0.54512056 -0.38022436] [ 0.00811955  0.93687141 -0.16599105 -0.39795619]
# [-0.52187253 -0.54350975  0.54205043 -0.20722052] [-0.38391654  0.64379653  0.1144356  -0.26362509]
# ../../../eval-fm/eval-gr/models/model_vp_2_v_OtherBenchC9Tanh_RBF_1_512_ReLU.h5
# 177
# ***** path idx 0 s_factor 0.01 correction steps 40
# Starting distance: 0.5798871725644366
# Final relative distance 0.0021698954467804744
# Min relative distance: 0.0021698954467804744
# Min iter: 6
# Before adaptation iterations: 6
# Final iterations: 6
# Time taken: 2.3320698738098145

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC9Tanh')
evalObject.setIterCount(500)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[-0.91036981, -0.41154395,  0.34706167, -0.1648444 ]])[0]
time_step = 114

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[-0.57901881, -0.17855466,  0.65901188, -0.28764357]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[10], scaling_factors=[0.01], i_state=[ref_traj[0]],
                             adaptation_run=False)
# Out:
# ../../../eval-fm/eval-gr/dconfigs_inv/d_object_OtherBenchC9Tanh.txt
# [-0.91036981 -0.41154395  0.34706167 -0.1648444 ] [-0.73828731  0.67585648  0.12704456 -0.21484489]
# [-0.57901881 -0.17855466  0.65901188 -0.28764357] [-0.3741663   0.49216114  0.30976951 -0.3188394 ]
# ../../../eval-fm/eval-gr/models/model_vp_2_v_OtherBenchC9Tanh_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.01 correction steps 10
# Starting distance: 0.45883695500323884
# Final relative distance 0.0038851827129337125
# Min relative distance: 0.0038851827129337125
# Min iter: 8
# Before adaptation iterations: 8
# Final iterations: 8
# Time taken: 3.5544345378875732

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC9Tanh')
evalObject.setIterCount(100)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[-0.64343721, -0.35481454, 0.31645362, -0.48215772]])[0]
time_step = 281

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[-0.94942456, -0.59297976, 0.20508661, -0.20818601]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[30], scaling_factors=[0.01],
                             i_state=[ref_traj[0]], adaptation_run=True)
# Out:
# ../../../eval-fm/eval-gr/dconfigs_inv/d_object_OtherBenchC9Tanh.txt
# [-0.64343721 -0.35481454  0.31645362 -0.48215772] [ 0.43744406  0.47015409 -1.00795839 -0.40777501]
# [-0.94942456 -0.59297976  0.20508661 -0.20818601] [ 0.6853023   0.82897056 -0.47958519 -0.21695601]
# ../../../eval-fm/eval-gr/models/model_vp_2_v_OtherBenchC9Tanh_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.01 correction steps 30
# Starting distance: 0.711177254814503
# Before adaptation relative distance 0.1391252706654749
# Final relative distance 0.004089906386812626
# Min relative distance: 0.004089906386812626
# Min iter: 46
# Before adaptation iterations: 4
# Final iterations: 46
# Time taken: 19.944159269332886

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC9Tanh')
evalObject.setIterCount(2000)
dataObject = evalObject.setDataObject()
dest_traj = dataObject.generateTrajectories(r_states=[[-0.64343721, -0.35481454, 0.31645362, -0.48215772]])[0]
time_step = 281

print(dest_traj[0], dest_traj[time_step])
dest = dest_traj[time_step]
dests = [dest]
ref_traj = dataObject.generateTrajectories(r_states=[[-0.94942456, -0.59297976, 0.20508661, -0.20818601]])[0]
print(ref_traj[0], ref_traj[time_step])
evalObject.reachDestInvPaths(dests=dests, d_time_steps=[time_step], threshold=0.005, 
                        correction_steps=[10, 20], scaling_factors=[0.01], 
                             i_state=[ref_traj[0]], adaptation_run=False)
# Out:
# ../../../eval-fm/eval-gr/dconfigs_inv/d_object_OtherBenchC9Tanh.txt
# [-0.64343721 -0.35481454  0.31645362 -0.48215772] [ 0.43744406  0.47015409 -1.00795839 -0.40777501]
# [-0.94942456 -0.59297976  0.20508661 -0.20818601] [ 0.6853023   0.82897056 -0.47958519 -0.21695601]
# ../../../eval-fm/eval-gr/models/model_vp_2_v_OtherBenchC9Tanh_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.01 correction steps 10
# Starting distance: 0.711177254814503
# Final relative distance 0.0064024017714829
# Min relative distance: 0.0064024017714829
# Min iter: 23
# Before adaptation iterations: 23
# Final iterations: 23
# Time taken: 6.491806745529175
# ***** path idx 0 s_factor 0.01 correction steps 20
# Starting distance: 0.711177254814503
# Final relative distance 0.004233383682334832
# Min relative distance: 0.004233383682334832
# Min iter: 32
# Before adaptation iterations: 32
# Final iterations: 32
# Time taken: 11.615387916564941
