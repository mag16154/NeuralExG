# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC4')
evalObject.setIterCount(50)
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([0.2, 0.2, 0.2])
dataObject.setUpperBound([0.7, 0.7, 0.7])


lowerBound = [1.0, 0.05, -1.15]
upperBound = [1.05, 0.10, -1.10]
evalObject.setUnsafeSet(lowerBound, upperBound)
dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_steps = [60, 70]

max_iter = 1
f_iterations = np.zeros(max_iter)
min_dists = np.zeros(max_iter)
idx = 0
while idx < max_iter:
    print("Idx *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    print(dests)
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=time_steps, threshold=0.002, correction_steps=[20],
                            scaling_factors=[0.01], i_state=[ref_traj[0]], adaptation_run=True)
    f_iter = evalObject.getFIterations()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_iter > 1 and rel_dist < 1.0:
        f_iterations[idx], min_dists[idx] = f_iter, min_dist
        idx = idx + 1
    else:
        print("** either f_iter is 1 or rel_dist is 1.0 **")
# print(f_iterations, min_rel_dists)
print(np.sum(f_iterations)/max_iter)
print(np.sum(min_dists)/max_iter)
print(np.max(f_iterations))
print(np.var(f_iterations))
# Out:
# ../../../eval-fm/eval-gr/dconfigs_inv/d_object_OtherBenchC4.txt
# Idx *** 0
# [[1.0207875373065354, 0.0638605255926039, -1.1074733494288633]]
# ../../../eval-fm/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# 65
# ***** path idx 0 s_factor 0.01 correction steps 20
# Starting distance: 0.44629477396688677
# Final relative distance 0.050061003559967
# Min relative distance: 0.050061003559967
# Min iter: 4
# Before adaptation iterations: 4
# Final iterations: 4
# Time taken: 2.769866704940796
# 4.0
# -0.02329664100349027
# 4.0
# 0.0

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC7')
evalObject.setIterCount(50)
dataObject = evalObject.setDataObject()
# dataObject.setSteps(150)

lowerBound = [0.05, 0.25, -0.35]
upperBound = [0.1, 0.3, -0.3]
evalObject.setUnsafeSet(lowerBound, upperBound)
dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_steps = [100, 110]

max_iter = 1
f_iterations = np.zeros(max_iter)
min_dists = np.zeros(max_iter)
idx = 0
while idx < max_iter:
    print("Idx *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    print(dests)
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=time_steps, threshold=0.0, correction_steps=[20],
                            scaling_factors=[0.01], i_state=[ref_traj[0]], adaptation_run=True)
    f_iter = evalObject.getFIterations()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_iter > 1 and rel_dist < 1.0:
        f_iterations[idx], min_dists[idx] = f_iter, min_dist
        idx = idx + 1
    else:
        print("** either f_iter is 1 or rel_dist is 1.0 **")
# print(f_iterations, min_rel_dists)
print(np.sum(f_iterations)/max_iter)
print(np.sum(min_dists)/max_iter)
print(np.max(f_iterations))
print(np.var(f_iterations))
# Out:
# ../../../eval-fm/eval-gr/dconfigs_inv/d_object_OtherBenchC7.txt
# Idx *** 0
# [[0.064387851978664, 0.29468941753322175, -0.30120913473613403]]
# ../../../eval-fm/eval-gr/models/model_vp_2_v_OtherBenchC7_RBF_1_512_ReLU.h5
# 105
# ***** path idx 0 s_factor 0.01 correction steps 20
# Starting distance: 0.26448510768163
# Final relative distance 0.039460405262448706
# Min relative distance: 0.039460405262448706
# Min iter: 3
# Before adaptation iterations: 3
# Final iterations: 3
# Time taken: 12.675854444503784
# 3.0
# -0.0001561163136853394
# 3.0
# 0.0

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC9Sigmoid', act_fn='Sigmoid')
evalObject.setIterCount(50)
dataObject = evalObject.setDataObject()
dataObject.setSteps(200)

lowerBound = [-0.55, 0.7, 0.65, 0.23]
upperBound = [-0.5, 0.75, 0.7, 0.28]
evalObject.setUnsafeSet(lowerBound, upperBound)
dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_steps = [110, 120]

max_iter = 1
f_iterations = np.zeros(max_iter)
min_dists = np.zeros(max_iter)
idx = 0
while idx < max_iter:
    print("Idx *** " + str(idx))
#     ref_traj = dataObject.generateTrajectories(r_states=[[-0.9428, -0.3688, 0.4219, -0.1164]])[0]
    ref_traj = dataObject.generateTrajectories(r_states=[[-0.9783, -0.2570, 0.5861, -0.2070]])[0]

    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    print(dests)
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=time_steps, threshold=0.0, correction_steps=[10],
                            scaling_factors=[0.01], i_state=[ref_traj[0]], adaptation_run=True)
    f_iter = evalObject.getFIterations()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_iter > 1 and rel_dist < 1.0:
        f_iterations[idx], min_dists[idx] = f_iter, min_dist
        idx = idx + 1
    else:
        print("** either f_iter is 1 or rel_dist is 1.0 **")
# print(f_iterations, min_rel_dists)
print(np.sum(f_iterations)/max_iter)
print(np.sum(min_dists)/max_iter)
print(np.max(f_iterations))
print(np.var(f_iterations))
# Out:
# ../../../eval-fm/eval-gr/dconfigs_inv/d_object_OtherBenchC9Sigmoid.txt
# Idx *** 0
# [[-0.5408945570650182, 0.7236915566219154, 0.6741136462220398, 0.2749507233402724]]
# ../../../eval-fm/eval-gr/models/model_vp_2_v_OtherBenchC9Sigmoid_RBF_1_512_Sigmoid.h5
# 115
# ***** path idx 0 s_factor 0.01 correction steps 10
# Starting distance: 0.1364435323064166
# Final relative distance 0.017904362184887283
# Min relative distance: 0.017904362184887283
# Min iter: 4
# Before adaptation iterations: 4
# Final iterations: 4
# Time taken: 1.381324291229248
# 4.0
# -0.00930402987106177
# 4.0
# 0.0

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../../core')
sys.path.append('../../../configuration-setup/')
sys.path.append('../../../core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC10')
evalObject.setIterCount(50)
dataObject = evalObject.setDataObject()
# dataObject.setSteps(150)

lowerBound = [8.4, -3.55, 2.52, 2.22]
upperBound = [8.45, -3.5, 2.55, 2.25]
evalObject.setUnsafeSet(lowerBound, upperBound)
dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_steps = [85, 95]

max_iter = 1
f_iterations = np.zeros(max_iter)
min_dists = np.zeros(max_iter)
idx = 0
while idx < max_iter:
    print("Idx *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(r_states=[[9.3184, -4.4182, 2.0733, 1.4248]])[0]

    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    print(dests)
    evalObject.reachDestInvPaths(dests=dests, d_time_steps=time_steps, threshold=0.0, correction_steps=[20],
                            scaling_factors=[0.01], i_state=[ref_traj[0]], adaptation_run=True)
    f_iter = evalObject.getFIterations()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_iter > 1 and rel_dist < 1.0:
        f_iterations[idx], min_dists[idx] = f_iter, min_dist
        idx = idx + 1
    else:
        print("** either f_iter is 1 or rel_dist is 1.0 **")
# print(f_iterations, min_rel_dists)
print(np.sum(f_iterations)/max_iter)
print(np.sum(min_dists)/max_iter)
print(np.max(f_iterations))
print(np.var(f_iterations))
# Out:
# ../../../eval-fm/eval-gr/dconfigs_inv/d_object_OtherBenchC10.txt
# Idx *** 0
# [[8.439911501462285, -3.5053856709827387, 2.5221573943244175, 2.243904865843157]]
# ../../../eval-fm/eval-gr/models/model_vp_2_v_OtherBenchC10_RBF_1_512_ReLU.h5
# 90
# ***** path idx 0 s_factor 0.01 correction steps 20
# Starting distance: 0.3696390064588025
# min dist -0.008851127799140102
# Final relative distance 0.14738977850071092
# Min relative distance: 0.14738977850071092
# Min iter: 3
# Before adaptation iterations: 3
# Final iterations: 3
# Time taken: 1.603132724761963
# 3.0
# -0.008851127799140102
# 3.0
# 0.0
